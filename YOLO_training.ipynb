# %%
# 1. ✅ Run this to import the environment

from env import UArmEnv
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
# To capture the image to make sure the camera is working properly
# ❌ This is not necessary to train, it's just for testing the environment and moving the arm to the desired position, 
# Use this to move and test the arm manually, or to capture images for training YOLO model

env = UArmEnv(render=False)  # use render=True if you want to see it
env.reset()

action = [0.0, 0.8, -1.57,0]

# Let the arm settle
for _ in range(10):
    env.step(action)
env.get_camera_image()
env.capture_single_image("test_image.png")
env.estimate_camera_bounds()
# Capture one image

env.close()
# Out:
# ✅ Saved image to test_image.png
# Camera Position: [ 0.02       -0.30593071  0.36003174]
# Camera Forward: [ 6.34136173e-07 -7.97458758e-04 -9.99999682e-01]
# Camera Target:  [ 0.02000063 -0.30672817 -0.63996794]
# ✅ Camera visible bounds:
# X_MIN = -0.170, X_MAX = 0.210
# Y_MIN = -0.490, Y_MAX = -0.120

# %%
# 2. ✅ Run this to generate the YOLO dataset

from env import UArmEnv
import os

def generate_yolo_dataset(n=1000, base_dir="./yolo/train_dataset"):
    env = UArmEnv(render=False)

    os.makedirs(os.path.join(base_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(base_dir, "labels"), exist_ok=True)

    for i in range(n):
        env.reset()
        action = [0.0, 0.8, -1.57, 0]
        for _ in range(10):
            env.step(action)
        env.get_camera_image()
        env.capture_image_and_dummy_label(base_dir, i)
        if i % 20 == 0:
            print(f"📸 Saved {i}/{n} samples...")

    env.close()
    print(f"✅ Dataset generation complete: {n} samples saved to '{base_dir}/'")
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
# 3. ✅ Run this to generate the YOLO dataset

generate_yolo_dataset(n=1000, base_dir="./yolo/train_dataset")
# Out:
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0000.png, train_dataset/labels/image_0000.txt
# 📸 Saved 0/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0001.png, train_dataset/labels/image_0001.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0002.png, train_dataset/labels/image_0002.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0003.png, train_dataset/labels/image_0003.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0004.png, train_dataset/labels/image_0004.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0005.png, train_dataset/labels/image_0005.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0006.png, train_dataset/labels/image_0006.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0007.png, train_dataset/labels/image_0007.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0008.png, train_dataset/labels/image_0008.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0009.png, train_dataset/labels/image_0009.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0010.png, train_dataset/labels/image_0010.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0011.png, train_dataset/labels/image_0011.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0012.png, train_dataset/labels/image_0012.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0013.png, train_dataset/labels/image_0013.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0014.png, train_dataset/labels/image_0014.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0015.png, train_dataset/labels/image_0015.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0016.png, train_dataset/labels/image_0016.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0017.png, train_dataset/labels/image_0017.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0018.png, train_dataset/labels/image_0018.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0019.png, train_dataset/labels/image_0019.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0020.png, train_dataset/labels/image_0020.txt
# 📸 Saved 20/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0021.png, train_dataset/labels/image_0021.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0022.png, train_dataset/labels/image_0022.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0023.png, train_dataset/labels/image_0023.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0024.png, train_dataset/labels/image_0024.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0025.png, train_dataset/labels/image_0025.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0026.png, train_dataset/labels/image_0026.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0027.png, train_dataset/labels/image_0027.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0028.png, train_dataset/labels/image_0028.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0029.png, train_dataset/labels/image_0029.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0030.png, train_dataset/labels/image_0030.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0031.png, train_dataset/labels/image_0031.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0032.png, train_dataset/labels/image_0032.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0033.png, train_dataset/labels/image_0033.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0034.png, train_dataset/labels/image_0034.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0035.png, train_dataset/labels/image_0035.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0036.png, train_dataset/labels/image_0036.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0037.png, train_dataset/labels/image_0037.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0038.png, train_dataset/labels/image_0038.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0039.png, train_dataset/labels/image_0039.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0040.png, train_dataset/labels/image_0040.txt
# 📸 Saved 40/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0041.png, train_dataset/labels/image_0041.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0042.png, train_dataset/labels/image_0042.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0043.png, train_dataset/labels/image_0043.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0044.png, train_dataset/labels/image_0044.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0045.png, train_dataset/labels/image_0045.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0046.png, train_dataset/labels/image_0046.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0047.png, train_dataset/labels/image_0047.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0048.png, train_dataset/labels/image_0048.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0049.png, train_dataset/labels/image_0049.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0050.png, train_dataset/labels/image_0050.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0051.png, train_dataset/labels/image_0051.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0052.png, train_dataset/labels/image_0052.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0053.png, train_dataset/labels/image_0053.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0054.png, train_dataset/labels/image_0054.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0055.png, train_dataset/labels/image_0055.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0056.png, train_dataset/labels/image_0056.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0057.png, train_dataset/labels/image_0057.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0058.png, train_dataset/labels/image_0058.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0059.png, train_dataset/labels/image_0059.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0060.png, train_dataset/labels/image_0060.txt
# 📸 Saved 60/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0061.png, train_dataset/labels/image_0061.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0062.png, train_dataset/labels/image_0062.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0063.png, train_dataset/labels/image_0063.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0064.png, train_dataset/labels/image_0064.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0065.png, train_dataset/labels/image_0065.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0066.png, train_dataset/labels/image_0066.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0067.png, train_dataset/labels/image_0067.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0068.png, train_dataset/labels/image_0068.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0069.png, train_dataset/labels/image_0069.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0070.png, train_dataset/labels/image_0070.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0071.png, train_dataset/labels/image_0071.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0072.png, train_dataset/labels/image_0072.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0073.png, train_dataset/labels/image_0073.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0074.png, train_dataset/labels/image_0074.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0075.png, train_dataset/labels/image_0075.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0076.png, train_dataset/labels/image_0076.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0077.png, train_dataset/labels/image_0077.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0078.png, train_dataset/labels/image_0078.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0079.png, train_dataset/labels/image_0079.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0080.png, train_dataset/labels/image_0080.txt
# 📸 Saved 80/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0081.png, train_dataset/labels/image_0081.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0082.png, train_dataset/labels/image_0082.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0083.png, train_dataset/labels/image_0083.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0084.png, train_dataset/labels/image_0084.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0085.png, train_dataset/labels/image_0085.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0086.png, train_dataset/labels/image_0086.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0087.png, train_dataset/labels/image_0087.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0088.png, train_dataset/labels/image_0088.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0089.png, train_dataset/labels/image_0089.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0090.png, train_dataset/labels/image_0090.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0091.png, train_dataset/labels/image_0091.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0092.png, train_dataset/labels/image_0092.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0093.png, train_dataset/labels/image_0093.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0094.png, train_dataset/labels/image_0094.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0095.png, train_dataset/labels/image_0095.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0096.png, train_dataset/labels/image_0096.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0097.png, train_dataset/labels/image_0097.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0098.png, train_dataset/labels/image_0098.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0099.png, train_dataset/labels/image_0099.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0100.png, train_dataset/labels/image_0100.txt
# 📸 Saved 100/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0101.png, train_dataset/labels/image_0101.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0102.png, train_dataset/labels/image_0102.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0103.png, train_dataset/labels/image_0103.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0104.png, train_dataset/labels/image_0104.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0105.png, train_dataset/labels/image_0105.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0106.png, train_dataset/labels/image_0106.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0107.png, train_dataset/labels/image_0107.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0108.png, train_dataset/labels/image_0108.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0109.png, train_dataset/labels/image_0109.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0110.png, train_dataset/labels/image_0110.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0111.png, train_dataset/labels/image_0111.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0112.png, train_dataset/labels/image_0112.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0113.png, train_dataset/labels/image_0113.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0114.png, train_dataset/labels/image_0114.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0115.png, train_dataset/labels/image_0115.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0116.png, train_dataset/labels/image_0116.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0117.png, train_dataset/labels/image_0117.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0118.png, train_dataset/labels/image_0118.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0119.png, train_dataset/labels/image_0119.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0120.png, train_dataset/labels/image_0120.txt
# 📸 Saved 120/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0121.png, train_dataset/labels/image_0121.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0122.png, train_dataset/labels/image_0122.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0123.png, train_dataset/labels/image_0123.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0124.png, train_dataset/labels/image_0124.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0125.png, train_dataset/labels/image_0125.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0126.png, train_dataset/labels/image_0126.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0127.png, train_dataset/labels/image_0127.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0128.png, train_dataset/labels/image_0128.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0129.png, train_dataset/labels/image_0129.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0130.png, train_dataset/labels/image_0130.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# ...
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0956.png, train_dataset/labels/image_0956.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0957.png, train_dataset/labels/image_0957.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0958.png, train_dataset/labels/image_0958.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0959.png, train_dataset/labels/image_0959.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0960.png, train_dataset/labels/image_0960.txt
# 📸 Saved 960/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0961.png, train_dataset/labels/image_0961.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0962.png, train_dataset/labels/image_0962.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0963.png, train_dataset/labels/image_0963.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0964.png, train_dataset/labels/image_0964.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0965.png, train_dataset/labels/image_0965.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0966.png, train_dataset/labels/image_0966.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0967.png, train_dataset/labels/image_0967.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0968.png, train_dataset/labels/image_0968.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0969.png, train_dataset/labels/image_0969.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0970.png, train_dataset/labels/image_0970.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0971.png, train_dataset/labels/image_0971.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0972.png, train_dataset/labels/image_0972.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0973.png, train_dataset/labels/image_0973.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0974.png, train_dataset/labels/image_0974.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0975.png, train_dataset/labels/image_0975.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0976.png, train_dataset/labels/image_0976.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0977.png, train_dataset/labels/image_0977.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0978.png, train_dataset/labels/image_0978.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0979.png, train_dataset/labels/image_0979.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0980.png, train_dataset/labels/image_0980.txt
# 📸 Saved 980/1000 samples...
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0981.png, train_dataset/labels/image_0981.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0982.png, train_dataset/labels/image_0982.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0983.png, train_dataset/labels/image_0983.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0984.png, train_dataset/labels/image_0984.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0985.png, train_dataset/labels/image_0985.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0986.png, train_dataset/labels/image_0986.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0987.png, train_dataset/labels/image_0987.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0988.png, train_dataset/labels/image_0988.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0989.png, train_dataset/labels/image_0989.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0990.png, train_dataset/labels/image_0990.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0991.png, train_dataset/labels/image_0991.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0992.png, train_dataset/labels/image_0992.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0993.png, train_dataset/labels/image_0993.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0994.png, train_dataset/labels/image_0994.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0995.png, train_dataset/labels/image_0995.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0996.png, train_dataset/labels/image_0996.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0997.png, train_dataset/labels/image_0997.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0998.png, train_dataset/labels/image_0998.txt
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image + YOLO label to: train_dataset/images/image_0999.png, train_dataset/labels/image_0999.txt
# ✅ Dataset generation complete: 1000 samples saved to 'train_dataset/'

# %%
# ❌ This is not necessary to for training purposes
# Visualise the captured image with bounding boxes
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("./yolo/train_dataset/images/image_0000.png")
h, w, _ = img.shape

with open("./yolo/train_dataset/labels/image_0000.txt") as f:
    for line in f:
        cls, cx, cy, bw, bh = map(float, line.strip().split())
        cx, cy, bw, bh = cx * w, cy * h, bw * w, bh * h
        x1, y1 = int(cx - bw / 2), int(cy - bh / 2)
        x2, y2 = int(cx + bw / 2), int(cy + bh / 2)
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(img, f"Class {int(cls)}", (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("YOLO Bounding Boxes")
plt.show()

# %%
# 4. ✅ Create the data.yaml file for YOLO training
yaml_content = """
train: ./yolo/train_dataset/images
val: ./train_dataset/images  # You can later create a val split

nc: 3
names: ['small', 'medium', 'large']
"""

with open("data.yaml", "w") as f:
    f.write(yaml_content.strip())

print("✅ data.yaml saved!")
# Out:
# ✅ data.yaml saved!

# %%
# 
# in bash terminal, run the following command to train the YOLO model:
# yolo task=detect mode=train model=yolov8n.pt data=./yolo/data.yaml epochs=100 imgsz=640

# And youre done with ttraining the YOLO model!

# %%
# loading the trained YOLO model and runs a test image

from ultralytics import YOLO

model = YOLO("./yolo/runs/detect/train/weights/best.pt")
results = model("./yolo/test_dataset/images/image_0000.png")

# Print results for first image
for box in results[0].boxes:
    cls = int(box.cls[0])
    conf = float(box.conf[0])
    x_center, y_center, w, h = map(float, box.xywhn[0])
    print(f"Class: {cls}, Confidence: {conf:.2f}, X: {x_center:.3f}, Y: {y_center:.3f}")
# Out:
# image 1/1 /home/fatduck/git/ai_project/main/UArm_robot_working/test_dataset/images/image_0000.png: 320x320 4 smalls, 4 mediums, 1 large, 4.3ms
# Speed: 0.6ms preprocess, 4.3ms inference, 110.8ms postprocess per image at shape (1, 3, 320, 320)
# Class: 0, Confidence: 0.99, X: 0.264, Y: 0.649
# Class: 1, Confidence: 0.99, X: 0.448, Y: 0.460
# Class: 1, Confidence: 0.98, X: 0.264, Y: 0.459
# Class: 0, Confidence: 0.98, X: 0.448, Y: 0.270
# Class: 2, Confidence: 0.98, X: 0.079, Y: 0.649
# Class: 1, Confidence: 0.98, X: 0.080, Y: 0.270
# Class: 1, Confidence: 0.98, X: 0.263, Y: 0.270
# Class: 0, Confidence: 0.98, X: 0.447, Y: 0.649
# Class: 0, Confidence: 0.95, X: 0.079, Y: 0.459

# %%
# I forgot why I did this. Is it the same as the first cell?

from env import UArmEnv
env = UArmEnv(render=False)
env.reset()
action = [0.0, 0.8, -1.57, 0]
for _ in range(10):
    env.step(action)
env.get_camera_image()
env.capture_image_label_and_gt("./yolo/test_dataset", image_index=0)
env.close()

# %%
from env import UArmEnv
from ultralytics import YOLO
import cv2
import numpy as np
import os

# Step 1: Run environment and capture ground truth + label
env = UArmEnv(render=False)
env.reset()
action = [0.0, 0.8, -1.57, 0]
for _ in range(10):
    env.step(action)

env.get_camera_image()
env.capture_image_label_and_gt("./yolo/test_dataset", image_index=0)
env.close()

# Step 2: Run YOLOv8 prediction on the saved image
image_path = "./yolo/test_dataset/images/image_0000.png"
model = YOLO("./yolo/runs/detect/train3/weights/best.pt")
results = model(image_path)

# Step 3: Convert YOLO predictions back to world coordinates
X_MIN, X_MAX = -0.170, 0.210
Y_MIN, Y_MAX = -0.490, -0.120

print("\n📍 YOLO Predicted World Coordinates:")
for box in results[0].boxes:
    cls = int(box.cls[0])
    conf = float(box.conf[0])
    x_center_n, y_center_n = map(float, box.xywhn[0][:2])

    # Convert back to world coordinates (reverse normalisation)
    x_world = X_MIN + (1.0 - x_center_n) * (X_MAX - X_MIN)
    y_world = Y_MIN + y_center_n * (Y_MAX - Y_MIN)

    

    print(f"Class {cls}, Confidence: {conf:.2f}, X: {x_world:.3f}, Y: {y_world:.3f}")
# Out:
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [    0.28907    -0.08025        0.03]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link✅ Saved image, label, and ground truth for image_0000
#
# image 1/1 /home/fatduck/git/ai_project/main/UArm_robot_working/test_dataset/images/image_0000.png: 640x640 4 smalls, 3 mediums, 2 larges, 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 📍 YOLO Predicted World Coordinates:
# Class 2, Confidence: 0.99, X: 0.110, Y: -0.390
# Class 2, Confidence: 0.99, X: 0.180, Y: -0.320
# Class 1, Confidence: 0.99, X: 0.110, Y: -0.250
# Class 0, Confidence: 0.99, X: 0.108, Y: -0.321
# Class 0, Confidence: 0.99, X: 0.039, Y: -0.320
# Class 1, Confidence: 0.99, X: 0.180, Y: -0.250
# Class 0, Confidence: 0.99, X: 0.039, Y: -0.389
# Class 0, Confidence: 0.99, X: 0.040, Y: -0.251
# Class 1, Confidence: 0.99, X: 0.180, Y: -0.390
