# %%
import datetime
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, CallbackList
from env import UArmEnv
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
env = DummyVecEnv([lambda: UArmEnv(render=False)])
eval_env = DummyVecEnv([lambda: UArmEnv(render=False)])
# Out:
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward

        if self.num_timesteps % self.log_interval == 0:
            current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            # ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"time: {current_time} 📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {self.cumulative_reward:.2f} | 🎯 Goal: {np.round(goal_pos, 3)}")
            self.cumulative_reward = 0
        return True

# %%
class CheckpointCallback(BaseCallback):
    def __init__(self, save_freq, save_path, name_prefix="model", verbose=1):
        super().__init__(verbose)
        self.save_freq = save_freq
        self.save_path = save_path
        self.name_prefix = name_prefix

    def _on_step(self) -> bool:
        if self.n_calls % self.save_freq == 0:
            path = f"{self.save_path}/{self.name_prefix}_{self.num_timesteps}.zip"
            self.model.save(path)
            if self.verbose:
                print(f"💾 Saved checkpoint to {path}")
        return True

# %%
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./ppo_checkpoints/",
    log_path="./ppo_checkpoints/",
    eval_freq=20000,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(
    save_freq=20000,
    save_path="./ppo_checkpoints/",
    name_prefix="ppo_uarm_checkpoint"
)

reward_logging_callback = RewardAndGoalLoggingCallback(log_interval=20000)

callback = CallbackList([
    eval_callback,
    checkpoint_callback,
    reward_logging_callback
])

# %%
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,
    n_steps=2048,
    batch_size=256,
    gae_lambda=0.95,
    gamma=0.99,
    verbose=0
)
# Out:
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
model.learn(total_timesteps=1_500_000, callback=callback)
model.save("ppo_uarm_final")
env.close()
# Out:
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.196  0.009] | Goal: [ 0.043 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.03   0.284] | Goal: [ 0.042 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [0.039 0.047 0.303] | Goal: [ 0.045 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.063  0.324] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.013 -0.189  0.039] | Goal: [ 0.111 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.12  -0.149  0.023] | Goal: [ 0.106 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.071 -0.22  -0.008] | Goal: [ 0.109 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.068  0.204] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.12   0.098] | Goal: [ 0.037 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.062  0.232] | Goal: [ 0.038 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.128  0.09 ] | Goal: [ 0.106 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.058 -0.133  0.191] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.145  0.185] | Goal: [ 0.041 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.097 -0.165  0.068] | Goal: [ 0.113 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.064 -0.129  0.165] | Goal: [ 0.04  -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.175  0.091] | Goal: [ 0.107 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.099  0.328] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.043 -0.037  0.285] | Goal: [ 0.114 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.11  -0.257  0.073] | Goal: [ 0.045 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.2    0.199] | Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.119 -0.11   0.181] | Goal: [ 0.108 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.001 -0.143  0.185] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.083 -0.077  0.19 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.081  0.187] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.155  0.122] | Goal: [ 0.042 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.218  0.077] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.129  0.13 ] | Goal: [ 0.107 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.194 -0.24   0.039] | Goal: [ 0.114 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.185  0.08 ] | Goal: [ 0.039 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.157  0.317] | Goal: [ 0.11  -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.213 -0.008] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.215 -0.224  0.183] | Goal: [ 0.109 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.179  0.075] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.15   0.057] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.147 -0.108  0.29 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.022  0.314] | Goal: [ 0.04  -0.247  0.06 ]
# 📊 Step 20000 | ✅ Successes: 6 | ⏱️ Timeouts: 36
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ⏱️ Timeout at Step 500 | EE: [-0.009 -0.191  0.072] | Goal: [ 0.035 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.005 -0.194  0.078] | Goal: [ 0.105 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.192  0.073] | Goal: [ 0.106 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.008 -0.194  0.077] | Goal: [ 0.038 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.005 -0.192  0.073] | Goal: [ 0.114 -0.324  0.025]
# Eval num_timesteps=20000, episode_reward=-77.67 +/- 17.39
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# time: 2025-06-20 15:25:37 📈 Step 20000 | Reward (last 20000): -5292.63 | 🎯 Goal: [ 0.042 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.167 -0.126 -0.011] | Goal: [ 0.042 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.031  0.268] | Goal: [ 0.044 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.082  0.174] | Goal: [ 0.041 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.013 -0.215 -0.005] | Goal: [ 0.112 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.157 -0.105  0.101] | Goal: [ 0.105 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.072 -0.166  0.117] | Goal: [ 0.037 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.18  -0.139  0.024] | Goal: [ 0.106 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.003 -0.189  0.004] | Goal: [ 0.043 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.08   0.162] | Goal: [ 0.044 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.054 -0.074  0.163] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.172  0.005] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.188 -0.005] | Goal: [ 0.044 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.005 -0.091  0.156] | Goal: [ 0.112 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.197  0.002] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.119  0.188] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.034 -0.179  0.218] | Goal: [ 0.112 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.128  0.134] | Goal: [ 0.105 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.159  0.077] | Goal: [ 0.115 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.115 -0.138  0.152] | Goal: [ 0.036 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.189  0.102] | Goal: [ 0.041 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.137  0.121] | Goal: [ 0.045 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.098 -0.1    0.145] | Goal: [ 0.04  -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.19   0.048] | Goal: [ 0.044 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.152 -0.225  0.106] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.093 -0.114  0.123] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.176  0.252] | Goal: [ 0.037 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.098  0.348] | Goal: [ 0.041 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.027 -0.142  0.188] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.064  0.223] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.192 -0.193 -0.009] | Goal: [ 0.045 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.013 -0.163  0.218] | Goal: [ 0.111 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.119 -0.114  0.107] | Goal: [ 0.041 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.004 -0.031  0.355] | Goal: [ 0.105 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.156  0.129] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.159  0.221] | Goal: [-0.169 -0.151  0.03 ]
# 📊 Step 40000 | ✅ Successes: 10 | ⏱️ Timeouts: 35
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.184  0.059] | Goal: [ 0.111 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.184  0.059] | Goal: [ 0.045 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.184  0.059] | Goal: [ 0.038 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.184  0.058] | Goal: [ 0.043 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.184  0.058] | Goal: [ 0.035 -0.319  0.025]
# Eval num_timesteps=40000, episode_reward=-57.65 +/- 15.54
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# time: 2025-06-20 15:26:23 📈 Step 40000 | Reward (last 20000): -4888.22 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.204  0.026] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.151  0.251] | Goal: [ 0.112 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.17  -0.232  0.089] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.001  0.254] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.167  0.101] | Goal: [ 0.109 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.215 -0.005] | Goal: [ 0.115 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.115 -0.152 -0.013] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.027 -0.3    0.077] | Goal: [ 0.043 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.204 -0.166  0.062] | Goal: [ 0.108 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.099  0.147] | Goal: [ 0.111 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.101 -0.25   0.048] | Goal: [ 0.042 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.081  0.153] | Goal: [ 0.111 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.177 -0.208  0.225] | Goal: [ 0.038 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.2    0.175] | Goal: [ 0.108 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.09  -0.171  0.226] | Goal: [ 0.038 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.207  0.17 ] | Goal: [ 0.04  -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.091  0.152] | Goal: [ 0.112 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.077 -0.153  0.091] | Goal: [ 0.038 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.009 -0.16   0.114] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.14   0.015] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.13  -0.091  0.119] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.112 -0.216  0.077] | Goal: [ 0.114 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.141 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.092  0.163] | Goal: [ 0.114 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.195 -0.008] | Goal: [ 0.038 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.184  0.128] | Goal: [ 0.04  -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.143 -0.004] | Goal: [ 0.106 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.082  0.319] | Goal: [ 0.112 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.233  0.059] | Goal: [ 0.108 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.147 -0.122  0.107] | Goal: [ 0.107 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.121  0.11 ] | Goal: [ 0.109 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.042 -0.261  0.185] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.089 -0.279  0.122] | Goal: [ 0.044 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.31   0.132] | Goal: [ 0.043 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.096 -0.21  -0.008] | Goal: [ 0.115 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.222  0.145] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.187  0.248] | Goal: [ 0.039 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.091  0.158] | Goal: [ 0.043 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.06  -0.174  0.066] | Goal: [ 0.106 -0.318  0.025]
# 📊 Step 60000 | ✅ Successes: 3 | ⏱️ Timeouts: 39
# ⏱️ Timeout at Step 500 | EE: [ 0.004 -0.183  0.065] | Goal: [ 0.035 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.026 -0.181  0.066] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.183  0.064] | Goal: [ 0.112 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.183  0.065] | Goal: [ 0.114 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.183  0.064] | Goal: [ 0.113 -0.323  0.025]
# Eval num_timesteps=60000, episode_reward=-77.47 +/- 21.76
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:27:07 📈 Step 60000 | Reward (last 20000): -4845.07 | 🎯 Goal: [ 0.044 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.23   0.142] | Goal: [ 0.044 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.135 -0.133  0.02 ] | Goal: [ 0.035 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.086 -0.13   0.112] | Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.132 -0.006] | Goal: [ 0.11  -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.153 -0.111  0.047] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.082 -0.1    0.136] | Goal: [ 0.04  -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.084 -0.093  0.14 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.113  0.221] | Goal: [ 0.114 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.142 -0.109  0.082] | Goal: [ 0.108 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.074 -0.082  0.146] | Goal: [ 0.043 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.193 -0.135  0.03 ] | Goal: [ 0.115 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.088  0.201] | Goal: [ 0.11  -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.194  0.163] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.149  0.081] | Goal: [ 0.043 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.187  0.045] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.159 -0.014] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.172  0.172] | Goal: [ 0.037 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.204 -0.009] | Goal: [ 0.11  -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.206 -0.004] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.117 -0.28   0.095] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.096  0.146] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.002 -0.202  0.119] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.212  0.067] | Goal: [ 0.036 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.024 -0.184  0.096] | Goal: [ 0.111 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.214 -0.008] | Goal: [ 0.114 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.026 -0.192  0.202] | Goal: [ 0.108 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.001 -0.203 -0.012] | Goal: [ 0.115 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.141 -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.196 -0.008] | Goal: [ 0.037 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.098  0.135] | Goal: [ 0.039 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.09   0.148] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.158  0.114] | Goal: [ 0.036 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.067 -0.212 -0.01 ] | Goal: [ 0.044 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.123 -0.171 -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.086 -0.17   0.222] | Goal: [ 0.11  -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.157  0.012] | Goal: [ 0.038 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.066 -0.142  0.127] | Goal: [ 0.106 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.065  0.152] | Goal: [ 0.037 -0.317  0.06 ]
# 📊 Step 80000 | ✅ Successes: 4 | ⏱️ Timeouts: 38
# ⏱️ Timeout at Step 500 | EE: [-0.013 -0.185  0.056] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.033 -0.184  0.049] | Goal: [ 0.107 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.186  0.05 ] | Goal: [ 0.037 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.186  0.05 ] | Goal: [ 0.043 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.184  0.05 ] | Goal: [ 0.114 -0.255  0.025]
# Eval num_timesteps=80000, episode_reward=-78.00 +/- 13.42
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:27:51 📈 Step 80000 | Reward (last 20000): -4815.60 | 🎯 Goal: [ 0.109 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.021 -0.074  0.252] | Goal: [ 0.109 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.121 -0.176 -0.005] | Goal: [ 0.112 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.195  0.052] | Goal: [ 0.11  -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.165 -0.007] | Goal: [ 0.045 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.152  0.065] | Goal: [ 0.111 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.182  0.079] | Goal: [ 0.037 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.16  -0.117 -0.002] | Goal: [ 0.041 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.006 -0.143  0.171] | Goal: [ 0.044 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.139  0.108] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.019 -0.129  0.137] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.146  0.307] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.106  0.108] | Goal: [ 0.109 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.107 -0.105  0.119] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.159 -0.007] | Goal: [ 0.111 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.003 -0.049  0.258] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.138  0.066] | Goal: [ 0.11  -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.138  0.088] | Goal: [ 0.11 -0.32  0.06]
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.187  0.009] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.141 -0.18   0.075] | Goal: [ 0.115 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.212 -0.006] | Goal: [ 0.043 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.026 -0.209 -0.004] | Goal: [ 0.037 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.184 -0.182  0.216] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.    -0.221  0.173] | Goal: [ 0.043 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.074 -0.103  0.18 ] | Goal: [ 0.04  -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.066 -0.2    0.034] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.105 -0.165  0.008] | Goal: [ 0.036 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.17  -0.014] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.001 -0.044  0.298] | Goal: [ 0.108 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.067 -0.167  0.076] | Goal: [ 0.044 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.098 -0.166  0.025] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.132  0.252] | Goal: [ 0.111 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.095 -0.177 -0.008] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.085 -0.197  0.059] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.042 -0.182  0.056] | Goal: [ 0.113 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.242  0.091] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.053 -0.19  -0.01 ] | Goal: [ 0.041 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.138 -0.143  0.046] | Goal: [ 0.112 -0.325  0.06 ]
# 📊 Step 100000 | ✅ Successes: 4 | ⏱️ Timeouts: 37
# ⏱️ Timeout at Step 500 | EE: [ 0.007 -0.187  0.047] | Goal: [ 0.109 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.01  -0.187  0.049] | Goal: [ 0.041 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.01  -0.187  0.047] | Goal: [ 0.037 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.188  0.045] | Goal: [ 0.114 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.01  -0.187  0.049] | Goal: [ 0.043 -0.25   0.025]
# Eval num_timesteps=100000, episode_reward=-65.99 +/- 17.12
# Episode length: 500.00 +/- 0.00
# 💾 Saved checkpoint to ./ppo_checkpoints//ppo_uarm_checkpoint_100000.zip
# time: 2025-06-20 15:28:36 📈 Step 100000 | Reward (last 20000): -4823.29 | 🎯 Goal: [ 0.112 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.128  0.128] | Goal: [ 0.112 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.063 -0.121  0.131] | Goal: [ 0.112 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.125  0.084] | Goal: [ 0.037 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.078 -0.157  0.294] | Goal: [ 0.112 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.034 -0.186 -0.006] | Goal: [ 0.105 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.159 -0.113 -0.007] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.186  0.034] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.167  0.007] | Goal: [ 0.112 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.223 -0.001] | Goal: [ 0.114 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.191 -0.009] | Goal: [ 0.043 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.188 -0.011] | Goal: [ 0.039 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.052 -0.134  0.125] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.122 -0.013] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.113 -0.192 -0.006] | Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.09  -0.202 -0.005] | Goal: [ 0.108 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.211  0.007] | Goal: [ 0.039 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.173  0.066] | Goal: [ 0.114 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.026 -0.069  0.185] | Goal: [ 0.111 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.085 -0.18   0.26 ] | Goal: [ 0.041 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.178 -0.173  0.192] | Goal: [ 0.11  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.026 -0.196 -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.145  0.014] | Goal: [ 0.037 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.063 -0.181  0.032] | Goal: [ 0.112 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.005 -0.118  0.143] | Goal: [ 0.04  -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.003 -0.189  0.213] | Goal: [ 0.114 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.076 -0.226  0.201] | Goal: [ 0.114 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.062 -0.191  0.047] | Goal: [ 0.044 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.156 -0.105  0.053] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.093  0.145] | Goal: [ 0.04  -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.104 -0.15   0.067] | Goal: [ 0.108 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.169  0.082] | Goal: [ 0.108 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.103  0.294] | Goal: [ 0.036 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.203 -0.186  0.038] | Goal: [ 0.039 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.15   0.079] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.141  0.132] | Goal: [ 0.043 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.192 -0.012] | Goal: [ 0.04  -0.322  0.025]
# 📊 Step 120000 | ✅ Successes: 10 | ⏱️ Timeouts: 36
# ⏱️ Timeout at Step 500 | EE: [-0.047 -0.178  0.062] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.182  0.06 ] | Goal: [ 0.039 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.031 -0.182  0.06 ] | Goal: [ 0.035 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.18   0.06 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.175  0.058] | Goal: [ 0.108 -0.323  0.025]
# Eval num_timesteps=120000, episode_reward=-61.65 +/- 18.18
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:29:26 📈 Step 120000 | Reward (last 20000): -4592.91 | 🎯 Goal: [ 0.039 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.067 -0.14   0.113] | Goal: [ 0.039 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.012 -0.148  0.122] | Goal: [ 0.036 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.063 -0.193 -0.001] | Goal: [ 0.037 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.087 -0.056  0.206] | Goal: [ 0.107 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.088 -0.206 -0.005] | Goal: [ 0.105 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.132 -0.134  0.044] | Goal: [ 0.113 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.141 -0.154 -0.007] | Goal: [ 0.105 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.195  0.046] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.201  0.003] | Goal: [ 0.106 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.134 -0.1    0.105] | Goal: [ 0.038 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.11  -0.117  0.11 ] | Goal: [ 0.044 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.187 -0.003] | Goal: [ 0.041 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.208 -0.008] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.062 -0.304  0.052] | Goal: [ 0.108 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.214 -0.004] | Goal: [ 0.107 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.146 -0.121  0.012] | Goal: [ 0.036 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.065 -0.177  0.068] | Goal: [ 0.039 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.156 -0.185  0.012] | Goal: [ 0.111 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.207 -0.009] | Goal: [ 0.106 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.054 -0.151  0.153] | Goal: [ 0.037 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.027 -0.187  0.008] | Goal: [ 0.113 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.336  0.108] | Goal: [ 0.111 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.167 -0.011] | Goal: [ 0.111 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.088  0.139] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.085  0.148] | Goal: [ 0.114 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.156  0.067] | Goal: [ 0.108 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.084 -0.186 -0.01 ] | Goal: [ 0.038 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.212 -0.001] | Goal: [ 0.113 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.011 -0.111  0.146] | Goal: [ 0.037 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.182  0.016] | Goal: [ 0.037 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.077 -0.174  0.024] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.003 -0.188 -0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.    -0.025  0.309] | Goal: [ 0.041 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.026 -0.169  0.092] | Goal: [ 0.113 -0.321  0.025]
# 📊 Step 140000 | ✅ Successes: 12 | ⏱️ Timeouts: 34
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.186  0.049] | Goal: [ 0.107 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.178  0.054] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.001 -0.187  0.048] | Goal: [ 0.039 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.058 -0.176  0.057] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.187  0.047] | Goal: [ 0.106 -0.319  0.025]
# Eval num_timesteps=140000, episode_reward=-74.68 +/- 10.25
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:30:16 📈 Step 140000 | Reward (last 20000): -4478.19 | 🎯 Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.122  0.142] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.134  0.089] | Goal: [ 0.113 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.075 -0.104  0.165] | Goal: [ 0.106 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.189  0.027] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.098 -0.169 -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.071 -0.143  0.113] | Goal: [ 0.114 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.161 -0.012] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.211 -0.007] | Goal: [ 0.04  -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.207 -0.004] | Goal: [ 0.041 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.029 -0.069  0.235] | Goal: [ 0.105 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.2   -0.011] | Goal: [ 0.105 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.002 -0.239  0.003] | Goal: [ 0.115 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.02  -0.216 -0.003] | Goal: [ 0.114 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.079 -0.184 -0.006] | Goal: [ 0.113 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.053 -0.09   0.163] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.116  0.142] | Goal: [ 0.04  -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.184 -0.18  -0.007] | Goal: [ 0.112 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.073 -0.093  0.142] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.021 -0.27  -0.009] | Goal: [ 0.035 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.197 -0.013] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.156  0.055] | Goal: [ 0.044 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.11  -0.168 -0.012] | Goal: [ 0.042 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.167  0.045] | Goal: [ 0.036 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.037 -0.212 -0.006] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.039 -0.12   0.192] | Goal: [ 0.11  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.159  0.068] | Goal: [ 0.106 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.138  0.028] | Goal: [ 0.108 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.041 -0.185 -0.011] | Goal: [ 0.042 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.033 -0.193  0.005] | Goal: [ 0.043 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.257 -0.22   0.117] | Goal: [ 0.106 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.011 -0.187 -0.001] | Goal: [ 0.107 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.243  0.029] | Goal: [ 0.041 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.089 -0.131  0.11 ] | Goal: [ 0.114 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.186 -0.237  0.04 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.007 -0.188 -0.007] | Goal: [ 0.039 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.121 -0.127  0.227] | Goal: [ 0.112 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.058 -0.202 -0.005] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.271  0.183] | Goal: [ 0.106 -0.325  0.06 ]
# 📊 Step 160000 | ✅ Successes: 4 | ⏱️ Timeouts: 38
# ⏱️ Timeout at Step 500 | EE: [ 0.033 -0.187  0.029] | Goal: [ 0.108 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.006 -0.189  0.034] | Goal: [ 0.037 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.187  0.033] | Goal: [ 0.105 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.06  -0.179  0.039] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.189  0.03 ] | Goal: [ 0.041 -0.32   0.06 ]
# 📊 Step 20000 | ✅ Successes: 0 | ⏱️ Timeouts: 40
# Eval num_timesteps=160000, episode_reward=-62.39 +/- 15.28
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:31:06 📈 Step 160000 | Reward (last 20000): -4658.88 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.181  0.028] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.095  0.205] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.024 -0.186 -0.014] | Goal: [ 0.035 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.129 -0.136 -0.002] | Goal: [ 0.042 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.172 -0.168 -0.01 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.225  0.05 ] | Goal: [ 0.043 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.015 -0.171  0.095] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.074 -0.186 -0.004] | Goal: [ 0.038 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.153 -0.01 ] | Goal: [ 0.114 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.185 -0.012] | Goal: [ 0.044 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.194 -0.006] | Goal: [ 0.037 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.15   0.04 ] | Goal: [ 0.107 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.153  0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.016 -0.129  0.158] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.004 -0.217  0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.143  0.076] | Goal: [ 0.112 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.121  0.138] | Goal: [ 0.039 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.003 -0.142  0.147] | Goal: [ 0.037 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.092 -0.169  0.019] | Goal: [ 0.04  -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.011 -0.124  0.167] | Goal: [ 0.039 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.14   0.222] | Goal: [ 0.042 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.127 -0.143  0.025] | Goal: [ 0.039 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.094 -0.148  0.088] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.178  0.108] | Goal: [ 0.04  -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.168  0.084] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.033 -0.251  0.077] | Goal: [ 0.115 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.076 -0.184  0.028] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.125  0.147] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.175  0.081] | Goal: [ 0.039 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.141 -0.006] | Goal: [ 0.114 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.105  0.239] | Goal: [ 0.114 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.037 -0.293  0.031] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.162  0.097] | Goal: [ 0.038 -0.319  0.06 ]
# 📊 Step 180000 | ✅ Successes: 12 | ⏱️ Timeouts: 33
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.187  0.042] | Goal: [ 0.035 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.183  0.039] | Goal: [ 0.109 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.021 -0.187  0.044] | Goal: [ 0.045 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.183  0.039] | Goal: [ 0.109 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.182  0.039] | Goal: [ 0.114 -0.245  0.06 ]
# Eval num_timesteps=180000, episode_reward=-53.75 +/- 10.44
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# time: 2025-06-20 15:31:56 📈 Step 180000 | Reward (last 20000): -4416.84 | 🎯 Goal: [ 0.045 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.191  0.022] | Goal: [ 0.107 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.05  -0.1    0.145] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.105  0.231] | Goal: [ 0.11  -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.132  0.067] | Goal: [ 0.036 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.228 -0.003] | Goal: [ 0.109 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.157  0.125] | Goal: [ 0.108 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.193  0.025] | Goal: [ 0.042 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.004 -0.117  0.144] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.018 -0.207 -0.003] | Goal: [ 0.109 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.069 -0.098  0.16 ] | Goal: [ 0.035 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.198 -0.011] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.16   0.025] | Goal: [ 0.04  -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.156 -0.18   0.066] | Goal: [ 0.109 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.186  0.066] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.016 -0.24   0.003] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.123 -0.143  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.051 -0.184 -0.003] | Goal: [ 0.041 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.025 -0.126  0.258] | Goal: [ 0.115 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.17   0.09 ] | Goal: [ 0.038 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.179  0.016] | Goal: [ 0.111 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.165 -0.212  0.179] | Goal: [ 0.036 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.196 -0.01 ] | Goal: [ 0.038 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.195 -0.009] | Goal: [ 0.112 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.186 -0.282  0.126] | Goal: [ 0.11  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.014 -0.194  0.042] | Goal: [ 0.036 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.245  0.055] | Goal: [ 0.11  -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.186 -0.007] | Goal: [ 0.045 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.106 -0.18  -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.178  0.074] | Goal: [ 0.035 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.132  0.02 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.091  0.134] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.328  0.048] | Goal: [ 0.108 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.109  0.127] | Goal: [-0.169 -0.151  0.03 ]
# 📊 Step 200000 | ✅ Successes: 15 | ⏱️ Timeouts: 33
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.189  0.022] | Goal: [ 0.038 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.181  0.012] | Goal: [ 0.11  -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.052 -0.183  0.017] | Goal: [ 0.108 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.189  0.026] | Goal: [ 0.043 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.163  0.057] | Goal: [-0.169 -0.221  0.03 ]
# Eval num_timesteps=200000, episode_reward=-90.12 +/- 35.76
# Episode length: 500.00 +/- 0.00
# 💾 Saved checkpoint to ./ppo_checkpoints//ppo_uarm_checkpoint_200000.zip
# time: 2025-06-20 15:32:45 📈 Step 200000 | Reward (last 20000): -4364.08 | 🎯 Goal: [ 0.11  -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.17  -0.011] | Goal: [ 0.04  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.091 -0.311  0.095] | Goal: [ 0.11  -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.093 -0.164 -0.005] | Goal: [ 0.115 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.291  0.032] | Goal: [ 0.038 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.203 -0.009] | Goal: [ 0.039 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.082 -0.145  0.115] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.143  0.082] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.142 -0.169  0.019] | Goal: [ 0.037 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.071 -0.173  0.077] | Goal: [ 0.038 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.17   0.044] | Goal: [ 0.105 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.171  0.019] | Goal: [ 0.113 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.141 -0.17  -0.013] | Goal: [ 0.114 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.088 -0.153  0.096] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.115  0.061] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.154  0.025] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.106 -0.154 -0.007] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.123 -0.01 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.103  0.318] | Goal: [ 0.04 -0.32  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.252  0.165] | Goal: [ 0.044 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.198 -0.003] | Goal: [ 0.038 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.331  0.092] | Goal: [ 0.106 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.129 -0.132  0.23 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.166 -0.179  0.139] | Goal: [ 0.113 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.126  0.202] | Goal: [ 0.114 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.265 -0.224  0.119] | Goal: [ 0.037 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.193  0.111] | Goal: [ 0.112 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.092  0.156] | Goal: [ 0.037 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.019 -0.325  0.119] | Goal: [ 0.04 -0.25  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.103 -0.234 -0.006] | Goal: [ 0.114 -0.321  0.025]
# 📊 Step 220000 | ✅ Successes: 27 | ⏱️ Timeouts: 29
# ⏱️ Timeout at Step 500 | EE: [ 0.037 -0.271  0.03 ] | Goal: [ 0.036 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.312  0.043] | Goal: [ 0.11  -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.306  0.035] | Goal: [ 0.109 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.273  0.02 ] | Goal: [ 0.041 -0.322  0.06 ]
# Eval num_timesteps=220000, episode_reward=-32.82 +/- 29.77
# Episode length: 401.40 +/- 197.20
# New best mean reward!
# time: 2025-06-20 15:33:32 📈 Step 220000 | Reward (last 20000): -4234.99 | 🎯 Goal: [ 0.039 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.132 -0.335  0.086] | Goal: [ 0.114 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.011 -0.364  0.101] | Goal: [ 0.04  -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.166 -0.01 ] | Goal: [ 0.038 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.277  0.116] | Goal: [ 0.106 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.083 -0.315  0.136] | Goal: [ 0.038 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.1   -0.132  0.291] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.104 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.179 -0.305  0.079] | Goal: [ 0.113 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.221  0.051] | Goal: [ 0.112 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.183 -0.251  0.094] | Goal: [ 0.11  -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.218  0.116] | Goal: [ 0.108 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.129 -0.323  0.072] | Goal: [ 0.043 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.167  0.095] | Goal: [ 0.044 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.104 -0.294  0.228] | Goal: [ 0.106 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.177 -0.158  0.025] | Goal: [ 0.037 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.253 -0.005] | Goal: [ 0.042 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.201 -0.012] | Goal: [ 0.045 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.125 -0.25   0.062] | Goal: [ 0.111 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.    -0.272 -0.006] | Goal: [ 0.114 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.172  0.089] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.078 -0.354  0.124] | Goal: [ 0.044 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.118  0.182] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.073 -0.176 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.167 -0.164  0.004] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.147 -0.14   0.081] | Goal: [ 0.11  -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.143 -0.121  0.056] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.077 -0.189  0.011] | Goal: [ 0.038 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.158 -0.107  0.023] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 240000 | ✅ Successes: 33 | ⏱️ Timeouts: 28
# ⏱️ Timeout at Step 500 | EE: [-0.121 -0.14   0.059] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.305  0.016] | Goal: [ 0.04 -0.32  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.149 -0.319  0.067] | Goal: [ 0.113 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.144 -0.325  0.074] | Goal: [ 0.115 -0.252  0.06 ]
# Eval num_timesteps=240000, episode_reward=-38.31 +/- 26.67
# Episode length: 400.80 +/- 198.40
# time: 2025-06-20 15:34:23 📈 Step 240000 | Reward (last 20000): -3939.47 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.103 -0.158  0.054] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.186 -0.207  0.148] | Goal: [ 0.108 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.155 -0.334  0.117] | Goal: [ 0.107 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.103 -0.161 -0.001] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.184 -0.316  0.13 ] | Goal: [ 0.107 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.086 -0.186 -0.004] | Goal: [ 0.037 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.219 -0.236  0.14 ] | Goal: [ 0.114 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.253  0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.114 -0.185  0.308] | Goal: [ 0.035 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.24   0.006] | Goal: [ 0.114 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.203 -0.194  0.247] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.205 -0.013] | Goal: [ 0.038 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.339  0.144] | Goal: [ 0.11  -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.209 -0.288  0.077] | Goal: [ 0.106 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.315  0.018] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.184 -0.182 -0.011] | Goal: [ 0.043 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.215 -0.202  0.079] | Goal: [ 0.108 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.132  0.067] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.    -0.243  0.123] | Goal: [ 0.043 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.083 -0.184 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.156  0.334] | Goal: [ 0.043 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.085 -0.218  0.297] | Goal: [ 0.037 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.133 -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.077 -0.186 -0.014] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.258 -0.262  0.114] | Goal: [ 0.11  -0.324  0.025]
# 📊 Step 260000 | ✅ Successes: 35 | ⏱️ Timeouts: 25
# ⏱️ Timeout at Step 500 | EE: [-0.114 -0.148  0.05 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.092 -0.319  0.034] | Goal: [ 0.044 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.319  0.041] | Goal: [ 0.041 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.314  0.039] | Goal: [ 0.035 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.169 -0.314  0.078] | Goal: [ 0.107 -0.32   0.06 ]
# Eval num_timesteps=260000, episode_reward=-41.95 +/- 6.61
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:35:15 📈 Step 260000 | Reward (last 20000): -3857.06 | 🎯 Goal: [ 0.112 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.15  -0.009] | Goal: [ 0.039 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.052 -0.208 -0.006] | Goal: [ 0.037 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.333  0.095] | Goal: [ 0.107 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.141 -0.161  0.022] | Goal: [ 0.11  -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.14   0.002] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.035 -0.289  0.005] | Goal: [ 0.044 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.167  0.227] | Goal: [ 0.041 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.11  -0.165  0.127] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.173 -0.187 -0.008] | Goal: [ 0.038 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.044 -0.3    0.062] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.193 -0.288  0.058] | Goal: [ 0.04  -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.176 -0.187  0.079] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.24  -0.166  0.143] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.049 -0.212  0.155] | Goal: [ 0.115 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.099 -0.181 -0.013] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.252 -0.258  0.099] | Goal: [ 0.108 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.281  0.224] | Goal: [ 0.044 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.303  0.038] | Goal: [ 0.041 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.306  0.1  ] | Goal: [ 0.107 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.037 -0.34   0.052] | Goal: [ 0.11  -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.127 -0.014] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.242  0.197] | Goal: [ 0.041 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.094 -0.164 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.222 -0.273  0.084] | Goal: [ 0.036 -0.252  0.025]
# 📊 Step 280000 | ✅ Successes: 39 | ⏱️ Timeouts: 24
# ⏱️ Timeout at Step 500 | EE: [ 0.041 -0.33   0.035] | Goal: [ 0.038 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.331  0.037] | Goal: [ 0.044 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.13  -0.33   0.073] | Goal: [ 0.113 -0.318  0.025]
# ...
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.234 -0.005] | Goal: [ 0.044 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.195 -0.258  0.034] | Goal: [ 0.111 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.346  0.102] | Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.166 -0.315  0.102] | Goal: [ 0.112 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.121 -0.214  0.105] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.103 -0.233  0.082] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 440000 | ✅ Successes: 76 | ⏱️ Timeouts: 21
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.312  0.015] | Goal: [ 0.041 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.159 -0.174  0.044] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.113 -0.302  0.021] | Goal: [ 0.107 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.3    0.002] | Goal: [ 0.042 -0.252  0.06 ]
# Eval num_timesteps=440000, episode_reward=-54.19 +/- 37.80
# Episode length: 400.60 +/- 198.80
# time: 2025-06-20 15:43:26 📈 Step 440000 | Reward (last 20000): -2914.98 | 🎯 Goal: [ 0.115 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.063 -0.34   0.055] | Goal: [ 0.115 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.097 -0.303  0.159] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.093 -0.23  -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.337  0.071] | Goal: [ 0.105 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.026 -0.309  0.011] | Goal: [ 0.039 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.027 -0.265 -0.008] | Goal: [ 0.044 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.093 -0.336  0.065] | Goal: [ 0.113 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.287  0.015] | Goal: [ 0.044 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.089 -0.346  0.087] | Goal: [ 0.108 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.227 -0.272  0.109] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.157 -0.157 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.04  -0.307  0.012] | Goal: [ 0.107 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.087 -0.236  0.089] | Goal: [ 0.041 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.16  -0.2    0.001] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 460000 | ✅ Successes: 92 | ⏱️ Timeouts: 14
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.291  0.013] | Goal: [ 0.11  -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.037 -0.298  0.016] | Goal: [ 0.036 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.153 -0.199  0.048] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.292  0.013] | Goal: [ 0.105 -0.255  0.06 ]
# Eval num_timesteps=460000, episode_reward=-55.99 +/- 35.19
# Episode length: 400.40 +/- 199.20
# time: 2025-06-20 15:44:26 📈 Step 460000 | Reward (last 20000): -2949.40 | 🎯 Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.007 -0.361  0.085] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.235 -0.01 ] | Goal: [ 0.105 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.084 -0.261  0.021] | Goal: [ 0.039 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.229 -0.204  0.077] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.119 -0.175 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.272  0.   ] | Goal: [ 0.111 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.293  0.054] | Goal: [ 0.107 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.159 -0.307  0.123] | Goal: [ 0.106 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.062 -0.27   0.096] | Goal: [ 0.043 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.272 -0.007] | Goal: [ 0.04 -0.25  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.015 -0.219 -0.007] | Goal: [ 0.043 -0.247  0.025]
# 📊 Step 480000 | ✅ Successes: 105 | ⏱️ Timeouts: 11
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.196  0.019] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.196  0.019] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.121 -0.295  0.018] | Goal: [ 0.108 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.043 -0.296  0.009] | Goal: [ 0.037 -0.248  0.06 ]
# Eval num_timesteps=480000, episode_reward=-63.80 +/- 33.58
# Episode length: 400.20 +/- 199.60
# time: 2025-06-20 15:45:33 📈 Step 480000 | Reward (last 20000): -2795.72 | 🎯 Goal: [ 0.044 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.071 -0.34   0.168] | Goal: [ 0.113 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.292  0.066] | Goal: [ 0.108 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.123 -0.273  0.001] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.07  -0.285  0.07 ] | Goal: [ 0.036 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.271  0.079] | Goal: [ 0.043 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.072 -0.167  0.198] | Goal: [ 0.037 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.031 -0.309  0.04 ] | Goal: [ 0.043 -0.253  0.06 ]
# 📊 Step 500000 | ✅ Successes: 125 | ⏱️ Timeouts: 7
# ⏱️ Timeout at Step 500 | EE: [-0.147 -0.215  0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.203  0.016] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.279  0.025] | Goal: [ 0.113 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.203  0.016] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.203  0.016] | Goal: [-0.169 -0.221  0.03 ]
# Eval num_timesteps=500000, episode_reward=-75.41 +/- 10.52
# Episode length: 500.00 +/- 0.00
# 💾 Saved checkpoint to ./ppo_checkpoints//ppo_uarm_checkpoint_500000.zip
# time: 2025-06-20 15:46:42 📈 Step 500000 | Reward (last 20000): -2727.56 | 🎯 Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.311  0.122] | Goal: [ 0.039 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.168 -0.263  0.031] | Goal: [ 0.112 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.266 -0.006] | Goal: [ 0.036 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.199 -0.296  0.131] | Goal: [ 0.114 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.245 -0.007] | Goal: [ 0.109 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.17  -0.294  0.134] | Goal: [ 0.114 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.313  0.142] | Goal: [ 0.036 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.119 -0.263  0.076] | Goal: [ 0.108 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.278 -0.009] | Goal: [ 0.109 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.314  0.06 ] | Goal: [ 0.11 -0.25  0.06]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.16  -0.012] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 520000 | ✅ Successes: 131 | ⏱️ Timeouts: 11
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.223  0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.288  0.029] | Goal: [ 0.106 -0.25   0.025]
# 📊 Step 60000 | ✅ Successes: 4 | ⏱️ Timeouts: 40
# ⏱️ Timeout at Step 500 | EE: [ 0.121 -0.287  0.028] | Goal: [ 0.114 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.158 -0.192  0.032] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.289  0.019] | Goal: [ 0.107 -0.247  0.06 ]
# Eval num_timesteps=520000, episode_reward=-56.45 +/- 20.97
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:47:53 📈 Step 520000 | Reward (last 20000): -2643.66 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.2    0.023] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.005 -0.258  0.124] | Goal: [ 0.041 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.105 -0.273  0.209] | Goal: [ 0.107 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.058 -0.307  0.092] | Goal: [ 0.11  -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.249 -0.006] | Goal: [ 0.04  -0.246  0.025]
# 📊 Step 540000 | ✅ Successes: 190 | ⏱️ Timeouts: 5
# ⏱️ Timeout at Step 500 | EE: [ 0.135 -0.292  0.021] | Goal: [ 0.114 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.287  0.024] | Goal: [ 0.111 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.128 -0.294  0.019] | Goal: [ 0.106 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.307  0.011] | Goal: [ 0.042 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.288  0.023] | Goal: [ 0.107 -0.249  0.025]
# Eval num_timesteps=540000, episode_reward=-72.72 +/- 3.03
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:49:15 📈 Step 540000 | Reward (last 20000): -2443.24 | 🎯 Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.301  0.044] | Goal: [ 0.036 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.352  0.089] | Goal: [ 0.044 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.058 -0.298  0.032] | Goal: [ 0.041 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.302  0.022] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.279  0.002] | Goal: [ 0.042 -0.254  0.025]
# 📊 Step 560000 | ✅ Successes: 169 | ⏱️ Timeouts: 5
# ⏱️ Timeout at Step 500 | EE: [ 0.067 -0.302  0.009] | Goal: [ 0.041 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.304  0.009] | Goal: [ 0.042 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.294  0.013] | Goal: [ 0.041 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.279  0.022] | Goal: [ 0.108 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.205  0.028] | Goal: [-0.169 -0.151  0.03 ]
# Eval num_timesteps=560000, episode_reward=-69.39 +/- 18.48
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:50:34 📈 Step 560000 | Reward (last 20000): -2451.65 | 🎯 Goal: [ 0.108 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.256  0.009] | Goal: [ 0.039 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.006 -0.257 -0.006] | Goal: [ 0.035 -0.249  0.06 ]
# 📊 Step 580000 | ✅ Successes: 211 | ⏱️ Timeouts: 2
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.283  0.03 ] | Goal: [ 0.112 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.29   0.012] | Goal: [ 0.109 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.119 -0.291  0.013] | Goal: [ 0.109 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.284  0.028] | Goal: [ 0.11  -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.295  0.025] | Goal: [ 0.039 -0.246  0.06 ]
# Eval num_timesteps=580000, episode_reward=-53.80 +/- 26.04
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:52:00 📈 Step 580000 | Reward (last 20000): -2312.42 | 🎯 Goal: [ 0.037 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.242  0.064] | Goal: [ 0.037 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.244  0.022] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.029 -0.278 -0.008] | Goal: [ 0.04  -0.249  0.06 ]
# 📊 Step 600000 | ✅ Successes: 259 | ⏱️ Timeouts: 3
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.286  0.024] | Goal: [ 0.107 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.3    0.02 ] | Goal: [ 0.043 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.279  0.039] | Goal: [ 0.106 -0.253  0.025]
# Eval num_timesteps=600000, episode_reward=-33.27 +/- 35.00
# Episode length: 300.80 +/- 243.97
# 💾 Saved checkpoint to ./ppo_checkpoints//ppo_uarm_checkpoint_600000.zip
# time: 2025-06-20 15:53:33 📈 Step 600000 | Reward (last 20000): -2133.07 | 🎯 Goal: [ 0.036 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.206 -0.156  0.042] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.22 -0.23  0.03] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.206 -0.242  0.058] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 620000 | ✅ Successes: 275 | ⏱️ Timeouts: 3
# ⏱️ Timeout at Step 500 | EE: [-0.17  -0.224 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.17  -0.224 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.276  0.005] | Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.284  0.019] | Goal: [ 0.043 -0.253  0.025]
# Eval num_timesteps=620000, episode_reward=-66.83 +/- 35.24
# Episode length: 400.80 +/- 198.40
# time: 2025-06-20 15:55:10 📈 Step 620000 | Reward (last 20000): -2069.68 | 🎯 Goal: [ 0.109 -0.253  0.025]
# 📊 Step 640000 | ✅ Successes: 315 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.295  0.013] | Goal: [ 0.036 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.268  0.034] | Goal: [ 0.113 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.279  0.013] | Goal: [ 0.11  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.171 -0.239  0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.051 -0.294  0.014] | Goal: [ 0.042 -0.315  0.06 ]
# Eval num_timesteps=640000, episode_reward=-67.34 +/- 25.76
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:56:56 📈 Step 640000 | Reward (last 20000): -1899.99 | 🎯 Goal: [ 0.044 -0.248  0.06 ]
# 📊 Step 660000 | ✅ Successes: 353 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.304  0.019] | Goal: [ 0.035 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.173 -0.242  0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.031 -0.286  0.04 ] | Goal: [ 0.036 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.287  0.038] | Goal: [ 0.04  -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.303  0.02 ] | Goal: [ 0.042 -0.317  0.06 ]
# Eval num_timesteps=660000, episode_reward=-57.01 +/- 25.70
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 15:58:49 📈 Step 660000 | Reward (last 20000): -1738.05 | 🎯 Goal: [-0.169 -0.151  0.03 ]
# 📊 Step 680000 | ✅ Successes: 437 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.286  0.031] | Goal: [ 0.039 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.173 -0.256  0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.103 -0.267  0.043] | Goal: [ 0.108 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.117 -0.292  0.017] | Goal: [ 0.107 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.096 -0.273  0.037] | Goal: [ 0.106 -0.25   0.025]
# Eval num_timesteps=680000, episode_reward=-43.54 +/- 28.70
# Episode length: 500.00 +/- 0.00
# time: 2025-06-20 16:00:57 📈 Step 680000 | Reward (last 20000): -1500.03 | 🎯 Goal: [ 0.04  -0.25   0.025]
# 📊 Step 700000 | ✅ Successes: 651 | ⏱️ Timeouts: 0
# 📊 Step 80000 | ✅ Successes: 3 | ⏱️ Timeouts: 40
# ⏱️ Timeout at Step 500 | EE: [ 0.024 -0.28   0.034] | Goal: [ 0.036 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.305  0.015] | Goal: [ 0.045 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.28   0.035] | Goal: [ 0.04  -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.276  0.04 ] | Goal: [ 0.035 -0.251  0.06 ]
# Eval num_timesteps=700000, episode_reward=-28.11 +/- 26.68
# Episode length: 400.40 +/- 199.20
# New best mean reward!
# 💾 Saved checkpoint to ./ppo_checkpoints//ppo_uarm_checkpoint_700000.zip
# time: 2025-06-20 16:03:49 📈 Step 700000 | Reward (last 20000): -934.42 | 🎯 Goal: [ 0.108 -0.322  0.025]
# 📊 Step 720000 | ✅ Successes: 803 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.267  0.04 ] | Goal: [ 0.107 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.119 -0.305  0.028] | Goal: [ 0.109 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.301  0.023] | Goal: [ 0.111 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.275  0.036] | Goal: [ 0.041 -0.245  0.025]
# Eval num_timesteps=720000, episode_reward=-26.70 +/- 25.89
# Episode length: 400.60 +/- 198.80
# New best mean reward!
# time: 2025-06-20 16:07:07 📈 Step 720000 | Reward (last 20000): -477.79 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 740000 | ✅ Successes: 1255 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.034 -0.268  0.04 ] | Goal: [ 0.041 -0.246  0.025]
# Eval num_timesteps=740000, episode_reward=-2.32 +/- 8.38
# Episode length: 102.00 +/- 199.00
# New best mean reward!
# time: 2025-06-20 16:11:48 📈 Step 740000 | Reward (last 20000): 599.97 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 760000 | ✅ Successes: 1738 | ⏱️ Timeouts: 0
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.265  0.048] | Goal: [ 0.035 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.041 -0.268  0.048] | Goal: [ 0.043 -0.25   0.025]
# Eval num_timesteps=760000, episode_reward=-6.84 +/- 10.68
# Episode length: 201.80 +/- 243.48
# time: 2025-06-20 16:17:49 📈 Step 760000 | Reward (last 20000): 1767.76 | 🎯 Goal: [-0.169 -0.291  0.03 ]
