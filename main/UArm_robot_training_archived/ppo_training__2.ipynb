# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)},f🤖 EE Pos: {np.round(ef_pos, 3)} ")
            self.cumulative_reward = 0

        return True

# %%
from stable_baselines3 import PPO
from env_2 import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=1
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=1_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_final_25")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ⏱️ Timeout at Step 500 | EE: [-0.042 -0.096  0.158] | Goal: [-0.169 -0.248  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.167 -0.294  0.133] | Goal: [ 0.114 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.052  0.247] | Goal: [ 0.035 -0.252  0.06 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 352      |
# |    ep_rew_mean     | -80      |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.036 -0.176  0.145] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.037 -0.081  0.237] | Goal: [-0.169 -0.178  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.243  0.264] | Goal: [ 0.039 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.145 -0.2    0.083] | Goal: [ 0.038 -0.247  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | -91.4       |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006651675 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | -0.00373    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00643    |
# |    std                  | 0.999       |
# |    value_loss           | 10.7        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.048 -0.144  0.159] | Goal: [ 0.106 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.215  0.017] | Goal: [-0.169 -0.248  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.24   0.066] | Goal: [ 0.108 -0.324  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | -91         |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008842516 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | -0.176      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.698       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00702    |
# |    std                  | 0.998       |
# |    value_loss           | 6.01        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.23   0.229] | Goal: [ 0.043 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.125 -0.117  0.167] | Goal: [ 0.043 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.275  0.103] | Goal: [ 0.106 -0.322  0.025]
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 397        |
# |    ep_rew_mean          | -90        |
# | time/                   |            |
# |    fps                  | 450        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00785096 |
# |    clip_fraction        | 0.0577     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.68      |
# |    explained_variance   | -0.114     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.792      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0064    |
# |    std                  | 1.01       |
# |    value_loss           | 3.39       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.26   0.2  ] | Goal: [ 0.106 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.097 -0.182  0.273] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.17   0.137] | Goal: [ 0.11  -0.318  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010088243 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.734       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 1           |
# |    value_loss           | 3.32        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.179  0.061] | Goal: [ 0.109 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.047 -0.28   0.173] | Goal: [ 0.109 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.124 -0.136  0.079] | Goal: [-0.169 -0.248  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 396          |
# |    ep_rew_mean          | -88.1        |
# | time/                   |              |
# |    fps                  | 444          |
# |    iterations           | 6            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0076883896 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.0456       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00515     |
# |    std                  | 1            |
# |    value_loss           | 3.79         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.149  0.031] | Goal: [ 0.112 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.177 -0.223  0.12 ] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.066 -0.128  0.203] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | -88         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008889308 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00519    |
# |    std                  | 0.997       |
# |    value_loss           | 4.54        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.231  0.001] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.219 -0.005] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 384          |
# |    ep_rew_mean          | -84.1        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 8            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0067027286 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.0821       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00475     |
# |    std                  | 1            |
# |    value_loss           | 4.44         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.167  0.009] | Goal: [ 0.041 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.116  0.141] | Goal: [ 0.041 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.074 -0.21   0.027] | Goal: [ 0.11  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.125  0.094] | Goal: [ 0.114 -0.316  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 394          |
# |    ep_rew_mean          | -85.1        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 9            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0076394863 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.0744       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.66         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00786     |
# |    std                  | 0.999        |
# |    value_loss           | 5.93         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.163 -0.298  0.116] | Goal: [ 0.114 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.134  0.252] | Goal: [ 0.106 -0.32   0.025]
# 📊 Step 20000 | ✅ Successes: 21 | ⏱️ Timeouts: 30
# 📈 Step 20000 | Reward (last 20000): -4280.8603 | 🎯 Goal: [ 0.113 -0.254  0.025],f🤖 EE Pos: [ 0.045 -0.273  0.092]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | -80.5        |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 10           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0066865413 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | -0.0648      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00334     |
# |    std                  | 1            |
# |    value_loss           | 3.36         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.113 -0.201  0.062] | Goal: [ 0.045 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.128 -0.282  0.162] | Goal: [-0.169 -0.248  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 375          |
# |    ep_rew_mean          | -78.6        |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 11           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075602685 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.0137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.64         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00744     |
# |    std                  | 1            |
# |    value_loss           | 7.8          |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.169  0.053] | Goal: [ 0.107 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.048 -0.22  -0.009] | Goal: [ 0.038 -0.316  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 364          |
# |    ep_rew_mean          | -74.9        |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 12           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0071689608 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.00963      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.63         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00684     |
# |    std                  | 1            |
# |    value_loss           | 5.07         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.033 -0.265  0.045] | Goal: [ 0.041 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.13  -0.235 -0.005] | Goal: [ 0.042 -0.317  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | -70.4       |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 13          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005186154 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | -0.00277    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.992       |
# |    value_loss           | 7.31        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.14   0.132] | Goal: [ 0.113 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.145 -0.265  0.024] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | -67.6        |
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 14           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0070801917 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.0408       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00455     |
# |    std                  | 0.993        |
# |    value_loss           | 7.33         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.182 -0.005] | Goal: [ 0.105 -0.323  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | -64.2       |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 15          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008183937 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.0656      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0054     |
# |    std                  | 0.992       |
# |    value_loss           | 6.55        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.187 -0.29   0.096] | Goal: [ 0.036 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.16   0.126] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.194 -0.004] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.05  -0.202  0.163] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -65.3        |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 16           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068547837 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.026        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.67         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00398     |
# |    std                  | 0.984        |
# |    value_loss           | 7.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | -58.5        |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 17           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0060517406 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00491     |
# |    std                  | 0.98         |
# |    value_loss           | 3.82         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.152  0.327] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.254  0.012] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.263  0.152] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | -56.5       |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 18          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005593368 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.0574      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0044     |
# |    std                  | 0.977       |
# |    value_loss           | 8.49        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.245 -0.204  0.166] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.211 -0.005] | Goal: [ 0.112 -0.251  0.06 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 291          |
# |    ep_rew_mean          | -52          |
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 19           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0077287937 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.11         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00627     |
# |    std                  | 0.975        |
# |    value_loss           | 4.57         |
# ------------------------------------------
# 📊 Step 40000 | ✅ Successes: 82 | ⏱️ Timeouts: 48
# 📈 Step 40000 | Reward (last 20000): -3265.3064 | 🎯 Goal: [-0.169 -0.318  0.03 ],f🤖 EE Pos: [-0.137 -0.271  0.038]
# ⏱️ Timeout at Step 500 | EE: [-0.072 -0.234  0.045] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.064 -0.269 -0.006] | Goal: [ 0.113 -0.325  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | -48.8        |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 20           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0065615214 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.57        |
# |    explained_variance   | 0.0662       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00619     |
# |    std                  | 0.972        |
# |    value_loss           | 5.85         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.324  0.049] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.23  -0.006] | Goal: [ 0.108 -0.318  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 21          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007143152 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.0982      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0063     |
# |    std                  | 0.964       |
# |    value_loss           | 5.57        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.179 -0.258  0.165] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.207  0.234] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | -43.7       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 22          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008525603 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 0.957       |
# |    value_loss           | 3.72        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.218  0.019] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.095 -0.18  -0.007] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | -38.9       |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 23          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007856741 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00499    |
# |    std                  | 0.956       |
# |    value_loss           | 5.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | -37.4        |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 24           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0055051027 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.176        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.99         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.948        |
# |    value_loss           | 8.78         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.104 -0.168  0.274] | Goal: [ 0.043 -0.246  0.06 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 242          |
# |    ep_rew_mean          | -37.9        |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 25           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0073471954 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.46        |
# |    explained_variance   | 0.058        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.24         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.948        |
# |    value_loss           | 5.25         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.104 -0.261 -0.009] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.312  0.15 ] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -36.5       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 26          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005918894 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0067     |
# |    std                  | 0.944       |
# |    value_loss           | 4.74        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.306  0.177] | Goal: [ 0.115 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.092 -0.207 -0.013] | Goal: [ 0.115 -0.324  0.025]
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 218        |
# |    ep_rew_mean          | -32.8      |
# | time/                   |            |
# |    fps                  | 389        |
# |    iterations           | 27         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00645336 |
# |    clip_fraction        | 0.0459     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.43      |
# |    explained_variance   | 0.318      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.46       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00443   |
# |    std                  | 0.94       |
# |    value_loss           | 5.97       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.215 -0.193 -0.002] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 28          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004793008 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | -0.0302     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00282    |
# |    std                  | 0.941       |
# |    value_loss           | 6.07        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.087 -0.336  0.089] | Goal: [ 0.04  -0.254  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | -27.6       |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 29          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005141788 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.939       |
# |    value_loss           | 4.77        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.101 -0.22  -0.007] | Goal: [-0.169 -0.318  0.03 ]
# 📊 Step 60000 | ✅ Successes: 168 | ⏱️ Timeouts: 64
# 📈 Step 60000 | Reward (last 20000): -2888.1471 | 🎯 Goal: [ 0.042 -0.248  0.025],f🤖 EE Pos: [ 0.219 -0.253  0.066]
# ⏱️ Timeout at Step 500 | EE: [ 0.073 -0.232 -0.005] | Goal: [ 0.106 -0.325  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 30          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005354781 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.01        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00546    |
# |    std                  | 0.937       |
# |    value_loss           | 7.02        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.206 -0.006] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 31          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004726178 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00436    |
# |    std                  | 0.931       |
# |    value_loss           | 3.42        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.171 -0.205 -0.009] | Goal: [ 0.042 -0.253  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | -25          |
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 32           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0045593046 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00379     |
# |    std                  | 0.927        |
# |    value_loss           | 4.15         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.104 -0.179 -0.011] | Goal: [ 0.039 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.154 -0.264  0.085] | Goal: [ 0.111 -0.251  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 193          |
# |    ep_rew_mean          | -25.7        |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 33           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0048799156 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.36        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.924        |
# |    value_loss           | 3.73         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.308  0.083] | Goal: [ 0.109 -0.324  0.025]
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 177        |
# |    ep_rew_mean          | -23.1      |
# | time/                   |            |
# |    fps                  | 372        |
# |    iterations           | 34         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00792794 |
# |    clip_fraction        | 0.0732     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.34      |
# |    explained_variance   | 0.0823     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.54       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00641   |
# |    std                  | 0.917      |
# |    value_loss           | 3.39       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.044 -0.26  -0.006] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.125 -0.259 -0.008] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 35          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003860158 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.0457      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.913       |
# |    value_loss           | 6.3         |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.149 -0.22  -0.005] | Goal: [ 0.04  -0.245  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -23.4       |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 36          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007470798 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.909       |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.255 -0.006] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.191 -0.245  0.031] | Goal: [ 0.108 -0.247  0.06 ]
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | -22.8      |
# | time/                   |            |
# |    fps                  | 368        |
# |    iterations           | 37         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00639395 |
# |    clip_fraction        | 0.0618     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.28      |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.08       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0053    |
# |    std                  | 0.908      |
# |    value_loss           | 6.16       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.28   0.016] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.177 -0.191  0.214] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.176 -0.195 -0.014] | Goal: [-0.169 -0.178  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | -25.4        |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 38           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0056180106 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.27        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.906        |
# |    value_loss           | 4.14         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.034 -0.269  0.127] | Goal: [ 0.04  -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.248 -0.007] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 39          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005578048 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00486    |
# |    std                  | 0.904       |
# |    value_loss           | 3.89        |
# -----------------------------------------
# 📊 Step 80000 | ✅ Successes: 252 | ⏱️ Timeouts: 80
# 📈 Step 80000 | Reward (last 20000): -2527.539 | 🎯 Goal: [ 0.041 -0.316  0.06 ],f🤖 EE Pos: [ 0.099 -0.198 -0.011]
# ⏱️ Timeout at Step 500 | EE: [-0.185 -0.284  0.054] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.113 -0.227 -0.005] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 40          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009179341 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00646    |
# |    std                  | 0.899       |
# |    value_loss           | 3.68        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.092 -0.264 -0.007] | Goal: [ 0.039 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.064 -0.205  0.037] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 41           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0074140695 |
# |    clip_fraction        | 0.091        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.24        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00598     |
# |    std                  | 0.899        |
# |    value_loss           | 3.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | -25.2        |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 42           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0063214577 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00372     |
# |    std                  | 0.895        |
# |    value_loss           | 4.31         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.222 -0.004] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.097 -0.219 -0.004] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 43          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007369742 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.21       |
# |    explained_variance   | 0.0587      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00473    |
# |    std                  | 0.893       |
# |    value_loss           | 3.39        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.118 -0.218 -0.004] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 4.88        |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 473         |
# |    time_elapsed         | 12636       |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.017996427 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.94        |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0851      |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | 0.012       |
# |    std                  | 0.331       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.35        |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 474         |
# |    time_elapsed         | 12717       |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.056921262 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.95        |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0593      |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | 0.0132      |
# |    std                  | 0.331       |
# |    value_loss           | 0.0672      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.62       |
# |    ep_rew_mean          | 1.71       |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 475        |
# |    time_elapsed         | 12808      |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.03058108 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.121      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0954     |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | 0.0116     |
# |    std                  | 0.331      |
# |    value_loss           | 0.111      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.9         |
# |    ep_rew_mean          | 1.74        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 476         |
# |    time_elapsed         | 12908       |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.025358249 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.97        |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0913      |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00267     |
# |    std                  | 0.33        |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.82        |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 477         |
# |    time_elapsed         | 13006       |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.011699813 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2           |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0583      |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | 0.00905     |
# |    std                  | 0.327       |
# |    value_loss           | 0.0636      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.31        |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 478         |
# |    time_elapsed         | 13112       |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.011098188 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.03        |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0693      |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | 0.00408     |
# |    std                  | 0.326       |
# |    value_loss           | 0.0966      |
# -----------------------------------------
# 📊 Step 980000 | ✅ Successes: 50876 | ⏱️ Timeouts: 407
# 📈 Step 980000 | Reward (last 20000): 7425.7479 | 🎯 Goal: [-0.169 -0.248  0.03 ],f🤖 EE Pos: [-0.159 -0.209 -0.011]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 479         |
# |    time_elapsed         | 13209       |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.018337738 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.05        |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | 0.00624     |
# |    std                  | 0.325       |
# |    value_loss           | 0.053       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.61        |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 480         |
# |    time_elapsed         | 13301       |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.027808622 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.08        |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.059       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | 0.00714     |
# |    std                  | 0.323       |
# |    value_loss           | 0.043       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.52        |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 481         |
# |    time_elapsed         | 13392       |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.010286199 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.1         |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0267      |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | 0.00399     |
# |    std                  | 0.323       |
# |    value_loss           | 0.0607      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.56        |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 482         |
# |    time_elapsed         | 13484       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.024789676 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.12        |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0555      |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | 0.00903     |
# |    std                  | 0.322       |
# |    value_loss           | 0.0613      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.01        |
# |    ep_rew_mean          | 1.72        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 483         |
# |    time_elapsed         | 13576       |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.025796749 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.14        |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.031       |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | 0.00754     |
# |    std                  | 0.323       |
# |    value_loss           | 0.0471      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99        |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 484         |
# |    time_elapsed         | 13670       |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.027086798 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.16        |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0576      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.323       |
# |    value_loss           | 0.0693      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.56        |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 485         |
# |    time_elapsed         | 13761       |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.011055519 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.18        |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0365      |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | 0.00827     |
# |    std                  | 0.322       |
# |    value_loss           | 0.0618      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.25        |
# |    ep_rew_mean          | 1.73        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 486         |
# |    time_elapsed         | 13858       |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.019711126 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.2         |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0865      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.00803     |
# |    std                  | 0.323       |
# |    value_loss           | 0.0542      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.43        |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 487         |
# |    time_elapsed         | 13942       |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.026936783 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.21        |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0558      |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | 0.00657     |
# |    std                  | 0.323       |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 488         |
# |    time_elapsed         | 14040       |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.032623895 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.22        |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0452      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.00254     |
# |    std                  | 0.325       |
# |    value_loss           | 0.1         |
# -----------------------------------------
# 📊 Step 1000000 | ✅ Successes: 55286 | ⏱️ Timeouts: 407
# 📈 Step 1000000 | Reward (last 20000): 7783.3594 | 🎯 Goal: [ 0.109 -0.322  0.025],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.08        |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 489         |
# |    time_elapsed         | 14129       |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.028021663 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.23        |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0436      |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | 0.00893     |
# |    std                  | 0.324       |
# |    value_loss           | 0.0534      |
# -----------------------------------------

# %%
model.save("ppo_uarm")
1 000 000
