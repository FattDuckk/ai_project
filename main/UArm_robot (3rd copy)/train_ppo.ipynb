# %%
from stable_baselines3 import PPO
from env import UArmEnv

env = UArmEnv(render=False)
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=200_000)
model.save("ppo_pickplace_green")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# [INFO] Trying to load URDF from: /home/fatduck/git/ai_project/main/UArm_robot/urdf/UArm.urdf
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link[INFO] End-effector set to link index 5
# Using cuda device
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:40, in _patch_env(env)
#      39 try:
# ---> 40     import shimmy
#      41 except ImportError as e:
#
# ModuleNotFoundError: No module named 'shimmy'
#
# The above exception was the direct cause of the following exception:
#
# ...
