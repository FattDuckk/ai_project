# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)},f🤖 EE Pos: {np.round(ef_pos, 3)} ")
            self.cumulative_reward = 0

        return True

# %%
from stable_baselines3 import PPO
from env_2 import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=0
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=1_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_final_25")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ⏱️ Timeout at Step 500 | EE: [-0.065 -0.175  0.106] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.144 -0.174  0.18 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.083 -0.144  0.155] | Goal: [ 0.041 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.217  0.056] | Goal: [ 0.039 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.234  0.126] | Goal: [ 0.035 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.18   0.06 ] | Goal: [ 0.036 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.26   0.236] | Goal: [ 0.039 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.102 -0.12   0.335] | Goal: [ 0.115 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.107 -0.26   0.111] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.198  0.162] | Goal: [ 0.113 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.245  0.088] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.178 -0.009] | Goal: [ 0.04  -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.05   0.259] | Goal: [ 0.044 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.227  0.062] | Goal: [ 0.11  -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.213  0.115] | Goal: [ 0.11  -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.24   0.13 ] | Goal: [ 0.113 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.159 -0.158 -0.011] | Goal: [ 0.04  -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.214  0.145] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.147  0.046] | Goal: [ 0.111 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.081 -0.204  0.054] | Goal: [ 0.04  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.013 -0.252 -0.012] | Goal: [ 0.114 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.206  0.131] | Goal: [ 0.041 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.153  0.153] | Goal: [ 0.11  -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.061 -0.181  0.051] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.083 -0.19   0.075] | Goal: [ 0.037 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.207  0.109] | Goal: [ 0.038 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.014 -0.207 -0.011] | Goal: [ 0.038 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.157 -0.009] | Goal: [ 0.044 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.08   0.132] | Goal: [ 0.036 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.223  0.096] | Goal: [ 0.113 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.092 -0.2    0.083] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.206  0.094] | Goal: [-0.169 -0.221  0.03 ]
# 📊 Step 20000 | ✅ Successes: 14 | ⏱️ Timeouts: 32
# 📈 Step 20000 | Reward (last 20000): -4413.3458 | 🎯 Goal: [ 0.044 -0.254  0.06 ],f🤖 EE Pos: [ 0.035 -0.199  0.022]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.17  -0.012] | Goal: [ 0.044 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.165 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.041 -0.11   0.266] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.    -0.222 -0.002] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.084  0.321] | Goal: [ 0.106 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.281  0.246] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.26   0.194] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.189  0.018] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.099  0.26 ] | Goal: [ 0.109 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.112  0.217] | Goal: [ 0.044 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.22  -0.219  0.05 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.212 -0.176  0.183] | Goal: [ 0.106 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.024 -0.224  0.224] | Goal: [ 0.114 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.248 -0.222  0.106] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.09  -0.226  0.029] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.276  0.067] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.147  0.155] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.012 -0.265  0.133] | Goal: [ 0.111 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.204 -0.202  0.008] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.181 -0.128  0.235] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.189 -0.009] | Goal: [ 0.105 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.028 -0.209  0.042] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.168  0.194] | Goal: [ 0.045 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.053 -0.219  0.045] | Goal: [ 0.035 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.192 -0.193  0.135] | Goal: [ 0.044 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.259 -0.014] | Goal: [ 0.042 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.036 -0.17   0.186] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.004 -0.178  0.082] | Goal: [ 0.04  -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.293  0.087] | Goal: [ 0.036 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.228  0.033] | Goal: [ 0.037 -0.317  0.025]
# 📊 Step 40000 | ✅ Successes: 39 | ⏱️ Timeouts: 62
# 📈 Step 40000 | Reward (last 20000): -4307.4736 | 🎯 Goal: [ 0.105 -0.316  0.025],f🤖 EE Pos: [-0.034 -0.209  0.278]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.29   0.115] | Goal: [ 0.105 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.218  0.133] | Goal: [ 0.037 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.169 -0.127  0.016] | Goal: [ 0.036 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.076  0.325] | Goal: [ 0.045 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.206  0.155] | Goal: [ 0.105 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.23   0.249] | Goal: [ 0.113 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.22  -0.24   0.099] | Goal: [ 0.038 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.215  0.015] | Goal: [ 0.039 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.052 -0.222 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.005 -0.289  0.205] | Goal: [ 0.107 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.127 -0.253  0.097] | Goal: [ 0.109 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.134 -0.15   0.164] | Goal: [ 0.041 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.095  0.303] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.212 -0.009] | Goal: [ 0.036 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.271  0.18 ] | Goal: [ 0.042 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.156  0.183] | Goal: [ 0.111 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.151 -0.142  0.208] | Goal: [ 0.039 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.13  -0.183  0.169] | Goal: [ 0.107 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.225  0.122] | Goal: [ 0.035 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.196  0.018] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.072 -0.207 -0.008] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.252  0.047] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.153 -0.159  0.055] | Goal: [ 0.037 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.246 -0.008] | Goal: [ 0.107 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.209  0.007] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.041 -0.18   0.104] | Goal: [ 0.112 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.089 -0.219  0.063] | Goal: [ 0.113 -0.321  0.06 ]
# 📊 Step 60000 | ✅ Successes: 67 | ⏱️ Timeouts: 89
# 📈 Step 60000 | Reward (last 20000): -3994.0477 | 🎯 Goal: [ 0.04  -0.316  0.06 ],f🤖 EE Pos: [ 0.013 -0.173  0.125]
# ⏱️ Timeout at Step 500 | EE: [ 0.171 -0.188  0.035] | Goal: [ 0.108 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.005 -0.163  0.157] | Goal: [ 0.106 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.025 -0.154  0.146] | Goal: [ 0.111 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.006 -0.201  0.036] | Goal: [ 0.041 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.223 -0.009] | Goal: [ 0.105 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.157  0.173] | Goal: [ 0.111 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.128 -0.221  0.072] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.185  0.24 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.157  0.142] | Goal: [ 0.036 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.114 -0.21  -0.007] | Goal: [ 0.114 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.265 -0.011] | Goal: [ 0.041 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.174  0.183] | Goal: [ 0.039 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.252  0.056] | Goal: [ 0.106 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.288  0.15 ] | Goal: [ 0.114 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.102  0.224] | Goal: [ 0.107 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.046 -0.277  0.093] | Goal: [ 0.115 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.026 -0.195  0.251] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.098 -0.26   0.032] | Goal: [ 0.114 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.092 -0.093  0.291] | Goal: [ 0.04  -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.036 -0.203  0.021] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.196  0.147] | Goal: [ 0.041 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.163 -0.268  0.063] | Goal: [ 0.113 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.102 -0.168  0.247] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.096 -0.211 -0.009] | Goal: [ 0.112 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.204  0.098] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.116 -0.218 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.216  0.02 ] | Goal: [ 0.107 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.153 -0.262  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.262  0.274] | Goal: [ 0.106 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.244  0.03 ] | Goal: [ 0.107 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.084 -0.337  0.084] | Goal: [ 0.108 -0.318  0.06 ]
# 📊 Step 80000 | ✅ Successes: 94 | ⏱️ Timeouts: 120
# 📈 Step 80000 | Reward (last 20000): -3904.1748 | 🎯 Goal: [ 0.035 -0.245  0.025],f🤖 EE Pos: [-0.    -0.238  0.031]
# ⏱️ Timeout at Step 500 | EE: [-0.028 -0.166  0.13 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.238  0.223] | Goal: [ 0.106 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.168  0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.217 -0.01 ] | Goal: [ 0.041 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.153 -0.135 -0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.077 -0.182  0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.18  -0.211  0.205] | Goal: [ 0.04  -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.191  0.055] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.148  0.207] | Goal: [ 0.111 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.21  -0.193  0.015] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.16  -0.183  0.162] | Goal: [ 0.107 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.098 -0.279  0.068] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.224  0.017] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.    -0.221  0.133] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.33   0.061] | Goal: [ 0.115 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.117 -0.212  0.016] | Goal: [ 0.106 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.316  0.196] | Goal: [ 0.04  -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.053 -0.162  0.201] | Goal: [ 0.042 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.237  0.012] | Goal: [ 0.036 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.155  0.27 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.252 -0.009] | Goal: [ 0.106 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.109 -0.273  0.093] | Goal: [ 0.038 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.101 -0.316  0.138] | Goal: [ 0.109 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.229  0.159] | Goal: [ 0.039 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.169  0.247] | Goal: [ 0.041 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.266 -0.226  0.06 ] | Goal: [ 0.106 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.19   0.237] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.137 -0.245  0.087] | Goal: [ 0.115 -0.318  0.025]
# 📊 Step 100000 | ✅ Successes: 133 | ⏱️ Timeouts: 148
# 📈 Step 100000 | Reward (last 20000): -3735.4389 | 🎯 Goal: [-0.169 -0.151  0.03 ],f🤖 EE Pos: [-0.093 -0.22  -0.011]
# ⏱️ Timeout at Step 500 | EE: [-0.193 -0.196  0.029] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.286  0.19 ] | Goal: [ 0.042 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.263 -0.001] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.073 -0.305  0.1  ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.079 -0.289  0.036] | Goal: [ 0.111 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.248  0.088] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.208  0.226] | Goal: [ 0.113 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.031 -0.274 -0.007] | Goal: [ 0.114 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.264  0.016] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.155 -0.168  0.021] | Goal: [ 0.042 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.28   0.128] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.22   0.029] | Goal: [ 0.108 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.039 -0.292  0.177] | Goal: [ 0.041 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.209 -0.284  0.105] | Goal: [ 0.106 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.065 -0.277  0.083] | Goal: [ 0.043 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.075 -0.197  0.002] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.097 -0.326  0.121] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.256  0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.074 -0.173  0.272] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 120000 | ✅ Successes: 186 | ⏱️ Timeouts: 167
# 📈 Step 120000 | Reward (last 20000): -3575.4004 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.135 -0.25   0.024]
# ⏱️ Timeout at Step 500 | EE: [-0.251 -0.229  0.087] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.252  0.183] | Goal: [ 0.039 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.025 -0.304  0.205] | Goal: [ 0.113 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.073 -0.188 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.152 -0.257  0.108] | Goal: [ 0.11  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.179 -0.261  0.117] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.093 -0.234  0.159] | Goal: [ 0.037 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.226 -0.008] | Goal: [ 0.109 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.289  0.004] | Goal: [ 0.106 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.03  -0.275  0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.195  0.115] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.127 -0.184  0.307] | Goal: [ 0.109 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.263 -0.239  0.139] | Goal: [ 0.113 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.352  0.126] | Goal: [ 0.044 -0.249  0.06 ]
# 📊 Step 140000 | ✅ Successes: 262 | ⏱️ Timeouts: 181
# 📈 Step 140000 | Reward (last 20000): -3251.147 | 🎯 Goal: [ 0.043 -0.248  0.025],f🤖 EE Pos: [ 0.107 -0.194 -0.006]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.175  0.093] | Goal: [ 0.109 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.333  0.086] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.183  0.017] | Goal: [ 0.106 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.115 -0.292  0.047] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.247  0.026] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.175 -0.289  0.047] | Goal: [ 0.106 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.276  0.193] | Goal: [ 0.109 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.203 -0.256  0.113] | Goal: [ 0.115 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.193 -0.235  0.14 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.342  0.062] | Goal: [ 0.041 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.278  0.145] | Goal: [ 0.112 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.132 -0.265  0.08 ] | Goal: [ 0.043 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.16  -0.273  0.099] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.212  0.017] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.022 -0.252  0.054] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.251 -0.008] | Goal: [ 0.11  -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.12  -0.19   0.228] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 160000 | ✅ Successes: 343 | ⏱️ Timeouts: 198
# 📈 Step 160000 | Reward (last 20000): -3086.8726 | 🎯 Goal: [ 0.107 -0.249  0.025],f🤖 EE Pos: [-0.018 -0.184  0.114]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.214 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.274  0.051] | Goal: [ 0.111 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.251 -0.238  0.089] | Goal: [ 0.107 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.247  0.121] | Goal: [ 0.036 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.03  -0.232  0.051] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.204  0.051] | Goal: [ 0.106 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.009 -0.224  0.132] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.173 -0.215 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.15  -0.185  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.089 -0.323  0.111] | Goal: [ 0.115 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.254  0.011] | Goal: [ 0.043 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.235 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.179 -0.291  0.05 ] | Goal: [ 0.04  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.179  0.268] | Goal: [ 0.111 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.01  -0.297  0.183] | Goal: [ 0.039 -0.246  0.06 ]
# 📊 Step 180000 | ✅ Successes: 451 | ⏱️ Timeouts: 213
# 📈 Step 180000 | Reward (last 20000): -2939.2789 | 🎯 Goal: [ 0.041 -0.321  0.06 ],f🤖 EE Pos: [ 0.071 -0.279  0.113]
# ⏱️ Timeout at Step 500 | EE: [-0.175 -0.134 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.191  0.215] | Goal: [ 0.113 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.281  0.064] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.147 -0.316  0.06 ] | Goal: [ 0.043 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.082 -0.298  0.009] | Goal: [ 0.041 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.17  -0.185  0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.182 -0.27   0.142] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.255  0.009] | Goal: [ 0.114 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.06  -0.205  0.022] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.347  0.057] | Goal: [ 0.036 -0.317  0.06 ]
# 📊 Step 200000 | ✅ Successes: 546 | ⏱️ Timeouts: 223
# 📈 Step 200000 | Reward (last 20000): -2839.6338 | 🎯 Goal: [ 0.114 -0.248  0.06 ],f🤖 EE Pos: [ 0.063 -0.214 -0.006]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.245 -0.008] | Goal: [ 0.111 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.062 -0.267 -0.007] | Goal: [ 0.107 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.174 -0.266  0.039] | Goal: [ 0.108 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.192 -0.173  0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.348  0.113] | Goal: [ 0.113 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.221 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.165 -0.193 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.244  0.168] | Goal: [ 0.04  -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.178  0.056] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.316  0.122] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.105 -0.296  0.076] | Goal: [ 0.113 -0.325  0.025]
# 📊 Step 220000 | ✅ Successes: 671 | ⏱️ Timeouts: 234
# 📈 Step 220000 | Reward (last 20000): -2664.7303 | 🎯 Goal: [ 0.038 -0.247  0.025],f🤖 EE Pos: [ 0.048 -0.185  0.174]
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.352  0.079] | Goal: [ 0.114 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.011 -0.354  0.101] | Goal: [ 0.044 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.082 -0.211  0.041] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.102 -0.229  0.   ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.046 -0.203 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.318  0.085] | Goal: [ 0.112 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.096 -0.296  0.072] | Goal: [ 0.041 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.214 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.162 -0.176  0.094] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.125 -0.215 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.21  -0.242  0.068] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.099 -0.228  0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.07  -0.254  0.049] | Goal: [ 0.107 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.206 -0.17   0.026] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 240000 | ✅ Successes: 775 | ⏱️ Timeouts: 248
# 📈 Step 240000 | Reward (last 20000): -2713.5112 | 🎯 Goal: [-0.169 -0.221  0.03 ],f🤖 EE Pos: [-0.121 -0.166  0.148]
# ⏱️ Timeout at Step 500 | EE: [-0.176 -0.124 -0.011] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.148 -0.138 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.185 -0.18   0.063] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.166 -0.184 -0.009] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.081 -0.232  0.085] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.011 -0.252  0.057] | Goal: [ 0.037 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.209 -0.224  0.103] | Goal: [ 0.113 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.228 -0.248  0.079] | Goal: [ 0.11  -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.21   0.121] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.233  0.023] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.261 -0.211  0.059] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.129 -0.31   0.072] | Goal: [ 0.111 -0.254  0.06 ]
# 📊 Step 260000 | ✅ Successes: 892 | ⏱️ Timeouts: 260
# 📈 Step 260000 | Reward (last 20000): -2491.6785 | 🎯 Goal: [ 0.039 -0.316  0.06 ],f🤖 EE Pos: [-0.083 -0.333  0.061]
# ⏱️ Timeout at Step 500 | EE: [-0.195 -0.155  0.107] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.195 -0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.068 -0.227  0.107] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.106 -0.216  0.086] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.124 -0.223  0.034] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.237 -0.243  0.051] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.062 -0.291  0.064] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.116 -0.18   0.253] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.181 -0.202 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.181 -0.163  0.075] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.183 -0.14  -0.001] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.158 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.24  -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.11  -0.205 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 280000 | ✅ Successes: 1023 | ⏱️ Timeouts: 274
# 📈 Step 280000 | Reward (last 20000): -2546.987 | 🎯 Goal: [-0.169 -0.151  0.03 ],f🤖 EE Pos: [-0.103 -0.193  0.049]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.315  0.059] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.167 -0.194  0.003] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.151 -0.228 -0.01 ] | Goal: [ 0.11  -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.17  -0.188 -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.304  0.169] | Goal: [ 0.106 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.158 -0.219 -0.007] | Goal: [ 0.108 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.353  0.079] | Goal: [ 0.11  -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.079 -0.264  0.081] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.071 -0.26  -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.234 -0.239  0.064] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.075 -0.234 -0.005] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.145 -0.329  0.097] | Goal: [ 0.115 -0.32   0.025]
# 📊 Step 300000 | ✅ Successes: 1177 | ⏱️ Timeouts: 286
# 📈 Step 300000 | Reward (last 20000): -2331.7309 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.128 -0.215  0.004]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.279  0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.282  0.193] | Goal: [ 0.106 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.224 -0.268  0.076] | Goal: [ 0.109 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.038 -0.247  0.024] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 320000 | ✅ Successes: 1349 | ⏱️ Timeouts: 290
# 📈 Step 320000 | Reward (last 20000): -2193.9128 | 🎯 Goal: [ 0.114 -0.253  0.06 ],f🤖 EE Pos: [ 0.076 -0.271 -0.007]
# ⏱️ Timeout at Step 500 | EE: [-0.224 -0.256  0.092] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.095 -0.272  0.19 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.197 -0.219  0.   ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.266  0.026] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 340000 | ✅ Successes: 1558 | ⏱️ Timeouts: 294
# 📈 Step 340000 | Reward (last 20000): -2142.9521 | 🎯 Goal: [ 0.036 -0.321  0.06 ],f🤖 EE Pos: [ 0.12  -0.235 -0.01 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.242 -0.01 ] | Goal: [ 0.115 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.115 -0.228  0.002] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.084 -0.238  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.343  0.063] | Goal: [ 0.105 -0.32   0.025]
# 📊 Step 360000 | ✅ Successes: 1759 | ⏱️ Timeouts: 298
# 📈 Step 360000 | Reward (last 20000): -2037.3216 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.18  -0.184 -0.007]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.246 -0.015] | Goal: [ 0.105 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.132 -0.309  0.105] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 380000 | ✅ Successes: 2011 | ⏱️ Timeouts: 300
# 📈 Step 380000 | Reward (last 20000): -1787.4974 | 🎯 Goal: [ 0.114 -0.321  0.025],f🤖 EE Pos: [ 0.137 -0.297  0.069]
# ⏱️ Timeout at Step 500 | EE: [-0.205 -0.229  0.065] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.071 -0.258  0.062] | Goal: [ 0.112 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.311  0.159] | Goal: [ 0.111 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.245  0.026] | Goal: [ 0.041 -0.246  0.06 ]
# 📊 Step 400000 | ✅ Successes: 2294 | ⏱️ Timeouts: 304
# 📈 Step 400000 | Reward (last 20000): -1632.5836 | 🎯 Goal: [ 0.109 -0.315  0.025],f🤖 EE Pos: [ 0.108 -0.33   0.059]
# ⏱️ Timeout at Step 500 | EE: [-0.179 -0.201 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 420000 | ✅ Successes: 2628 | ⏱️ Timeouts: 305
# 📈 Step 420000 | Reward (last 20000): -1491.909 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.186 -0.278  0.059]
# 📊 Step 440000 | ✅ Successes: 3058 | ⏱️ Timeouts: 305
# 📈 Step 440000 | Reward (last 20000): -1214.8893 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.109 -0.23   0.027]
# 📊 Step 460000 | ✅ Successes: 3536 | ⏱️ Timeouts: 305
# 📈 Step 460000 | Reward (last 20000): -1062.2409 | 🎯 Goal: [ 0.108 -0.246  0.06 ],f🤖 EE Pos: [ 0.081 -0.259 -0.005]
# 📊 Step 480000 | ✅ Successes: 4081 | ⏱️ Timeouts: 305
# 📈 Step 480000 | Reward (last 20000): -884.0683 | 🎯 Goal: [ 0.037 -0.325  0.06 ],f🤖 EE Pos: [ 0.048 -0.288 -0.008]
# 📊 Step 500000 | ✅ Successes: 4679 | ⏱️ Timeouts: 305
# 📈 Step 500000 | Reward (last 20000): -712.9898 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.179 -0.256  0.023]
# 📊 Step 520000 | ✅ Successes: 5431 | ⏱️ Timeouts: 305
# 📈 Step 520000 | Reward (last 20000): -363.0529 | 🎯 Goal: [ 0.109 -0.251  0.025],f🤖 EE Pos: [ 0.116 -0.248  0.141]
# 📊 Step 540000 | ✅ Successes: 6271 | ⏱️ Timeouts: 305
# 📈 Step 540000 | Reward (last 20000): -133.0042 | 🎯 Goal: [-0.169 -0.291  0.03 ],f🤖 EE Pos: [-0.188 -0.258  0.036]
# 📊 Step 560000 | ✅ Successes: 7114 | ⏱️ Timeouts: 305
# 📈 Step 560000 | Reward (last 20000): -87.0827 | 🎯 Goal: [ 0.109 -0.321  0.025],f🤖 EE Pos: [ 0.113 -0.304  0.052]
# 📊 Step 580000 | ✅ Successes: 8222 | ⏱️ Timeouts: 305
# 📈 Step 580000 | Reward (last 20000): 511.017 | 🎯 Goal: [ 0.114 -0.25   0.025],f🤖 EE Pos: [ 0.125 -0.31   0.072]
# 📊 Step 600000 | ✅ Successes: 9438 | ⏱️ Timeouts: 305
# 📈 Step 600000 | Reward (last 20000): 774.4487 | 🎯 Goal: [ 0.109 -0.248  0.06 ],f🤖 EE Pos: [ 0.112 -0.319  0.066]
# 📊 Step 620000 | ✅ Successes: 10833 | ⏱️ Timeouts: 305
# 📈 Step 620000 | Reward (last 20000): 1168.2066 | 🎯 Goal: [ 0.041 -0.247  0.06 ],f🤖 EE Pos: [ 0.037 -0.248  0.096]
# 📊 Step 640000 | ✅ Successes: 12386 | ⏱️ Timeouts: 305
# 📈 Step 640000 | Reward (last 20000): 1549.375 | 🎯 Goal: [ 0.044 -0.254  0.06 ],f🤖 EE Pos: [ 0.033 -0.325  0.058]
# 📊 Step 660000 | ✅ Successes: 14004 | ⏱️ Timeouts: 305
# 📈 Step 660000 | Reward (last 20000): 1688.1973 | 🎯 Goal: [ 0.039 -0.245  0.06 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 680000 | ✅ Successes: 15807 | ⏱️ Timeouts: 305
# 📈 Step 680000 | Reward (last 20000): 2102.8989 | 🎯 Goal: [ 0.036 -0.254  0.025],f🤖 EE Pos: [ 0.034 -0.301  0.076]
# 📊 Step 700000 | ✅ Successes: 17682 | ⏱️ Timeouts: 305
# 📈 Step 700000 | Reward (last 20000): 2284.8899 | 🎯 Goal: [ 0.043 -0.317  0.025],f🤖 EE Pos: [ 0.037 -0.343  0.056]
# 📊 Step 720000 | ✅ Successes: 19791 | ⏱️ Timeouts: 305
# 📈 Step 720000 | Reward (last 20000): 2801.8963 | 🎯 Goal: [ 0.039 -0.321  0.025],f🤖 EE Pos: [ 0.048 -0.338  0.052]
# 📊 Step 740000 | ✅ Successes: 22074 | ⏱️ Timeouts: 305
# 📈 Step 740000 | Reward (last 20000): 3233.4652 | 🎯 Goal: [ 0.042 -0.247  0.025],f🤖 EE Pos: [ 0.061 -0.325  0.056]
# 📊 Step 760000 | ✅ Successes: 24634 | ⏱️ Timeouts: 305
# 📈 Step 760000 | Reward (last 20000): 3836.6335 | 🎯 Goal: [ 0.038 -0.32   0.025],f🤖 EE Pos: [ 0.038 -0.334  0.045]
# 📊 Step 780000 | ✅ Successes: 27569 | ⏱️ Timeouts: 305
# 📈 Step 780000 | Reward (last 20000): 4642.0037 | 🎯 Goal: [-0.169 -0.221  0.03 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 800000 | ✅ Successes: 30972 | ⏱️ Timeouts: 305
# 📈 Step 800000 | Reward (last 20000): 5640.8678 | 🎯 Goal: [ 0.113 -0.318  0.025],f🤖 EE Pos: [ 0.124 -0.303  0.069]
# 📊 Step 820000 | ✅ Successes: 34881 | ⏱️ Timeouts: 305
# 📈 Step 820000 | Reward (last 20000): 6693.1783 | 🎯 Goal: [ 0.044 -0.245  0.025],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 840000 | ✅ Successes: 39398 | ⏱️ Timeouts: 305
# 📈 Step 840000 | Reward (last 20000): 8000.3285 | 🎯 Goal: [ 0.107 -0.322  0.06 ],f🤖 EE Pos: [ 0.109 -0.296  0.018]
# 📊 Step 860000 | ✅ Successes: 44457 | ⏱️ Timeouts: 305
# 📈 Step 860000 | Reward (last 20000): 9162.5415 | 🎯 Goal: [ 0.039 -0.325  0.025],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 880000 | ✅ Successes: 50420 | ⏱️ Timeouts: 305
# 📈 Step 880000 | Reward (last 20000): 11065.0205 | 🎯 Goal: [ 0.044 -0.316  0.06 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 900000 | ✅ Successes: 56959 | ⏱️ Timeouts: 305
# 📈 Step 900000 | Reward (last 20000): 12277.1123 | 🎯 Goal: [ 0.045 -0.252  0.025],f🤖 EE Pos: [ 0.043 -0.274  0.105]
# 📊 Step 920000 | ✅ Successes: 64467 | ⏱️ Timeouts: 305
# 📈 Step 920000 | Reward (last 20000): 14261.2318 | 🎯 Goal: [-0.169 -0.221  0.03 ],f🤖 EE Pos: [-0.16  -0.211  0.047]
# 📊 Step 940000 | ✅ Successes: 72414 | ⏱️ Timeouts: 305
# 📈 Step 940000 | Reward (last 20000): 15166.3931 | 🎯 Goal: [ 0.114 -0.25   0.06 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 960000 | ✅ Successes: 80879 | ⏱️ Timeouts: 305
# 📈 Step 960000 | Reward (last 20000): 16243.8543 | 🎯 Goal: [ 0.039 -0.248  0.025],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 980000 | ✅ Successes: 89578 | ⏱️ Timeouts: 305
# 📈 Step 980000 | Reward (last 20000): 16739.4018 | 🎯 Goal: [-0.169 -0.221  0.03 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# 📊 Step 1000000 | ✅ Successes: 98560 | ⏱️ Timeouts: 305
# 📈 Step 1000000 | Reward (last 20000): 17309.8166 | 🎯 Goal: [ 0.041 -0.249  0.06 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]

# %%
model.save("ppo_uarm")
1 000 000
