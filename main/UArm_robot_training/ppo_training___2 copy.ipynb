# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)},f🤖 EE Pos: {np.round(ef_pos, 3)} ")
            self.cumulative_reward = 0

        return True

# %%
from stable_baselines3 import PPO
from env__2 import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=1
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=1_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_30_2__2_final")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkUsing cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.184 -0.202  0.038] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0297
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.146 -0.155  0.029] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0324
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03715928 -0.31518266  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03967333 -0.32291409  0.075     ]
# 🎉 Goal reached! EE: [ 0.051 -0.326  0.101] | Goal: [ 0.04  -0.323  0.075] | Reward: -0.0283
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03895089 -0.31640712  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 366      |
# |    ep_rew_mean     | -148     |
# | time/              |          |
# |    fps             | 325      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18340008 -0.39421227  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17813078 -0.38575903  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04260608 -0.38732261  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 426         |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010087676 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | -0.0154     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.997       |
# |    value_loss           | 39.1        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17589372 -0.31796708  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18428784 -0.24881451  0.075     ]
# 🎉 Goal reached! EE: [ 0.169 -0.265  0.048] | Goal: [ 0.184 -0.249  0.075] | Reward: -0.0348
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11121849 -0.25287671  0.075     ]
# 🎉 Goal reached! EE: [ 0.095 -0.234  0.074] | Goal: [ 0.111 -0.253  0.075] | Reward: -0.0244
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.158 -0.194  0.032] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0203
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | -179         |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0082732905 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | -0.0648      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.9         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00785     |
# |    std                  | 0.994        |
# |    value_loss           | 42.1         |
# ------------------------------------------
# 🎉 Goal reached! EE: [-0.149 -0.191  0.036] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0252
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17514338 -0.38644827  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03924427 -0.39456328  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11022574 -0.31766182  0.075     ]
# 🎉 Goal reached! EE: [ 0.1   -0.298  0.1  ] | Goal: [ 0.11  -0.318  0.075] | Reward: -0.0331
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10830506 -0.31988544  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17724842 -0.39375425  0.075     ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | -170         |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0061387536 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | -0.154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.11         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0056      |
# |    std                  | 0.993        |
# |    value_loss           | 25.6         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10743389 -0.39213732  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.196 -0.236  0.042] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0316
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03768996 -0.32316072  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17998957 -0.25128264  0.03      ]
# 🎉 Goal reached! EE: [ 0.179 -0.217  0.036] | Goal: [ 0.18  -0.251  0.03 ] | Reward: -0.0346
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | -172        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007503327 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | -0.00993    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.74        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00873    |
# |    std                  | 0.991       |
# |    value_loss           | 24.3        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.176 -0.178  0.03 ] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.007
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18106783 -0.38837284  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10621235 -0.31786505  0.03      ]
# 🎉 Goal reached! EE: [ 0.096 -0.317  0.054] | Goal: [ 0.106 -0.318  0.03 ] | Reward: -0.026
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11088723 -0.31809506  0.075     ]
# 🎉 Goal reached! EE: [ 0.096 -0.301  0.084] | Goal: [ 0.111 -0.318  0.075] | Reward: -0.0244
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.154 -0.241  0.049] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0252
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04345235 -0.3231559   0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | -162         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 6            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067551127 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | -0.0485      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.56         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00625     |
# |    std                  | 0.986        |
# |    value_loss           | 16.1         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17890051 -0.31943693  0.03      ]
# 🎉 Goal reached! EE: [ 0.179 -0.292  0.05 ] | Goal: [ 0.179 -0.319  0.03 ] | Reward: -0.0336
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.145 -0.247  0.038] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0255
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11246762 -0.31871839  0.03      ]
# 🎉 Goal reached! EE: [ 0.115 -0.306  0.051] | Goal: [ 0.112 -0.319  0.03 ] | Reward: -0.0245
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.154 -0.242  0.018] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0206
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04286345 -0.38769319  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17723506 -0.39026978  0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 7            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063694715 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.0155       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.18         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.004       |
# |    std                  | 0.978        |
# |    value_loss           | 15.6         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.165 -0.173  0.04 ] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0117
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04484898 -0.24709314  0.075     ]
# 🎉 Goal reached! EE: [ 0.076 -0.242  0.086] | Goal: [ 0.045 -0.247  0.075] | Reward: -0.0339
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11264224 -0.3930031   0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 364          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 8            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0080649685 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.0127       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.83         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00596     |
# |    std                  | 0.976        |
# |    value_loss           | 16           |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18393779 -0.24597506  0.075     ]
# 🎉 Goal reached! EE: [ 0.189 -0.235  0.056] | Goal: [ 0.184 -0.246  0.075] | Reward: -0.0222
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.183 -0.257  0.015] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0222
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04475232 -0.31698784  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17541348 -0.24686762  0.075     ]
# 🎉 Goal reached! EE: [ 0.148 -0.228  0.067] | Goal: [ 0.175 -0.247  0.075] | Reward: -0.0338
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.201 -0.191  0.026] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0343
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10570477 -0.32054479  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18397191 -0.24841185  0.03      ]
# 🎉 Goal reached! EE: [ 0.162 -0.227  0.017] | Goal: [ 0.184 -0.248  0.03 ] | Reward: -0.0327
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03924596 -0.32439931  0.075     ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 353          |
# |    ep_rew_mean          | -146         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 9            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057139546 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.57        |
# |    explained_variance   | 0.0243       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.14         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.968        |
# |    value_loss           | 13.3         |
# ------------------------------------------
# 🎉 Goal reached! EE: [ 0.047 -0.346  0.065] | Goal: [ 0.039 -0.324  0.075] | Reward: -0.0247
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18027448 -0.24773705  0.075     ]
# 🎉 Goal reached! EE: [ 0.168 -0.238  0.066] | Goal: [ 0.18  -0.248  0.075] | Reward: -0.0185
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10681925 -0.25257207  0.075     ]
# 🎉 Goal reached! EE: [ 0.104 -0.245  0.095] | Goal: [ 0.107 -0.253  0.075] | Reward: -0.0216
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04060069 -0.24954375  0.075     ]
# 🎉 Goal reached! EE: [ 0.009 -0.263  0.069] | Goal: [ 0.041 -0.25   0.075] | Reward: -0.0343
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 📊 Step 20000 | ✅ Successes: 29 | ⏱️ Timeouts: 29
# 📈 Step 20000 | Reward (last 20000): -8177.8163 | 🎯 Goal: [-0.169 -0.248  0.03 ],f🤖 EE Pos: [ 0.088 -0.186  0.007]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03524288 -0.32403501  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 10          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013995631 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.0004      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00802    |
# |    std                  | 0.965       |
# |    value_loss           | 17.1        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.162 -0.298  0.055] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0329
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03704772 -0.38579005  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11342457 -0.38782306  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1062923  -0.39168849  0.075     ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006582756 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | -0.0188     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.8         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00352    |
# |    std                  | 0.97        |
# |    value_loss           | 19.1        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10600595 -0.39125943  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11384887 -0.39179392  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04227535 -0.32468783  0.075     ]
# 🎉 Goal reached! EE: [ 0.013 -0.329  0.086] | Goal: [ 0.042 -0.325  0.075] | Reward: -0.0318
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04020721 -0.38733452  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 12          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008508844 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.00181     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00266    |
# |    std                  | 0.967       |
# |    value_loss           | 11.5        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03953911 -0.32272344  0.075     ]
# 🎉 Goal reached! EE: [ 0.049 -0.315  0.101] | Goal: [ 0.04  -0.323  0.075] | Reward: -0.0289
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.149 -0.292  0.042] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0348
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11298426 -0.31572928  0.075     ]
# 🎉 Goal reached! EE: [ 0.127 -0.301  0.053] | Goal: [ 0.113 -0.316  0.075] | Reward: -0.03
# Goal position set to: [-0.16939274 -0.24760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link🎉 Goal reached! EE: [-0.161 -0.245  0.021] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0126
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.154 -0.173  0.046] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0224
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18052627 -0.25235023  0.075     ]
# 🎉 Goal reached! EE: [ 0.156 -0.26   0.081] | Goal: [ 0.181 -0.252  0.075] | Reward: -0.0264
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10878655 -0.31914703  0.075     ]
# 🎉 Goal reached! EE: [ 0.113 -0.31   0.08 ] | Goal: [ 0.109 -0.319  0.075] | Reward: -0.0112
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18158737 -0.39188677  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.141 -0.256  0.025] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0303
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.193 -0.252  0.043] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0272
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 13           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0066373562 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | -0.000947    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.4          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.96         |
# |    value_loss           | 14.4         |
# ------------------------------------------
# 🎉 Goal reached! EE: [-0.167 -0.297  0.053] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.031
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1117715  -0.38601033  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10869658 -0.31820989  0.03      ]
# 🎉 Goal reached! EE: [ 0.127 -0.309  0.052] | Goal: [ 0.109 -0.318  0.03 ] | Reward: -0.0305
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.146 -0.304  0.052] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0345
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18184616 -0.3874487   0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.168 -0.239  0.012] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0194
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 14          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007007853 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.000984    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00496    |
# |    std                  | 0.952       |
# |    value_loss           | 33.1        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04268415 -0.38743258  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11339409 -0.31915722  0.075     ]
# 🎉 Goal reached! EE: [ 0.121 -0.306  0.082] | Goal: [ 0.113 -0.319  0.075] | Reward: -0.0166
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17610903 -0.32199907  0.075     ]
# 🎉 Goal reached! EE: [ 0.171 -0.296  0.096] | Goal: [ 0.176 -0.322  0.075] | Reward: -0.0336
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.158 -0.303  0.047] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0252
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10745554 -0.38965425  0.075     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17939601 -0.24855315  0.03      ]
# 🎉 Goal reached! EE: [ 0.167 -0.25   0.022] | Goal: [ 0.179 -0.249  0.03 ] | Reward: -0.0152
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.162 -0.152  0.044] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0304
# ...
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18436165 -0.25172016  0.075     ]
# 🎉 Goal reached! EE: [ 0.152 -0.246  0.085] | Goal: [ 0.184 -0.252  0.075] | Reward: -0.0339
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17508849 -0.31677209  0.075     ]
# 🎉 Goal reached! EE: [ 0.159 -0.321  0.084] | Goal: [ 0.175 -0.317  0.075] | Reward: -0.0192
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18372436 -0.31911128  0.075     ]
# 🎉 Goal reached! EE: [ 0.178 -0.311  0.089] | Goal: [ 0.184 -0.319  0.075] | Reward: -0.0175
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10998138 -0.25196824  0.075     ]
# 🎉 Goal reached! EE: [ 0.104 -0.271  0.092] | Goal: [ 0.11  -0.252  0.075] | Reward: -0.0266
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10826082 -0.25434047  0.03      ]
# 🎉 Goal reached! EE: [ 0.083 -0.248  0.014] | Goal: [ 0.108 -0.254  0.03 ] | Reward: -0.0304
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10510204 -0.25381696  0.03      ]
# 🎉 Goal reached! EE: [ 0.092 -0.252  0.045] | Goal: [ 0.105 -0.254  0.03 ] | Reward: -0.0202
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17623826 -0.24643802  0.03      ]
# 🎉 Goal reached! EE: [ 0.153 -0.264  0.014] | Goal: [ 0.176 -0.246  0.03 ] | Reward: -0.0331
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.196 -0.247  0.017] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.03
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.149 -0.188  0.039] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0249
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04337115 -0.39470356  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18418913 -0.32079533  0.03      ]
# 🎉 Goal reached! EE: [ 0.171 -0.298  0.051] | Goal: [ 0.184 -0.321  0.03 ] | Reward: -0.0339
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11395129 -0.32420962  0.075     ]
# 🎉 Goal reached! EE: [ 0.126 -0.305  0.075] | Goal: [ 0.114 -0.324  0.075] | Reward: -0.0224
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17563564 -0.39205604  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04235175 -0.39081744  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.172 -0.299  0.059] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0349
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.161 -0.198  0.041] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0251
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1092484  -0.25485862  0.075     ]
# 🎉 Goal reached! EE: [ 0.108 -0.268  0.089] | Goal: [ 0.109 -0.255  0.075] | Reward: -0.0194
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18249171 -0.38619775  0.075     ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -7.17        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 488          |
# |    time_elapsed         | 4224         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0076616416 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.367        |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 0.387        |
# |    value_loss           | 0.7          |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18404255 -0.31598981  0.03      ]
# 🎉 Goal reached! EE: [ 0.174 -0.297  0.053] | Goal: [ 0.184 -0.316  0.03 ] | Reward: -0.0313
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11314623 -0.39400752  0.03      ]
# 📊 Step 1000000 | ✅ Successes: 5450 | ⏱️ Timeouts: 1625
# 📈 Step 1000000 | Reward (last 20000): -1412.2713 | 🎯 Goal: [ 0.113 -0.394  0.03 ],f🤖 EE Pos: [ 0.097 -0.344  0.079]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11093254 -0.39366122  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.174 -0.25   0.014] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0167
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.15  -0.192  0.025] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0252
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03708403 -0.25281075  0.075     ]
# 🎉 Goal reached! EE: [ 0.05  -0.258  0.05 ] | Goal: [ 0.037 -0.253  0.075] | Reward: -0.0281
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03963094 -0.2472564   0.03      ]
# 🎉 Goal reached! EE: [ 0.05  -0.268  0.055] | Goal: [ 0.04  -0.247  0.03 ] | Reward: -0.0338
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03672195 -0.38600257  0.075     ]
# 🎉 Goal reached! EE: [ 0.027 -0.357  0.082] | Goal: [ 0.037 -0.386  0.075] | Reward: -0.0312
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18412999 -0.25079189  0.03      ]
# 🎉 Goal reached! EE: [ 0.167 -0.226  0.021] | Goal: [ 0.184 -0.251  0.03 ] | Reward: -0.0313
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18179231 -0.25095573  0.03      ]
# 🎉 Goal reached! EE: [ 0.175 -0.27   0.052] | Goal: [ 0.182 -0.251  0.03 ] | Reward: -0.0303
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04494502 -0.25078495  0.03      ]
# 🎉 Goal reached! EE: [ 0.041 -0.274  0.012] | Goal: [ 0.045 -0.251  0.03 ] | Reward: -0.0291
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.164 -0.235 -0.002] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0346
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# Goal position set to: [ 0.10531521 -0.31967299  0.075     ]
# camera_link🎉 Goal reached! EE: [ 0.123 -0.319  0.104] | Goal: [ 0.105 -0.32   0.075] | Reward: -0.0337
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.174 -0.189  0.052] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0252
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11401227 -0.32273284  0.03      ]
# 🎉 Goal reached! EE: [ 0.093 -0.318  0.04 ] | Goal: [ 0.114 -0.323  0.03 ] | Reward: -0.0235
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# Goal position set to: [ 0.10843419 -0.31805115  0.075     ]
# camera_link🎉 Goal reached! EE: [ 0.113 -0.319  0.059] | Goal: [ 0.108 -0.318  0.075] | Reward: -0.0166
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04427095 -0.38726597  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.0435096  -0.39458351  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -8.05       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 489         |
# |    time_elapsed         | 4234        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.013191113 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.358      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.384       |
# |    value_loss           | 0.926       |
# -----------------------------------------

# %%
model.save("ppo_uarm")
1 000 000
