# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)},f🤖 EE Pos: {np.round(ef_pos, 3)} ")
            self.cumulative_reward = 0

        return True

# %%
from stable_baselines3 import PPO
from env import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=0
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=1_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_pos_final_30")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.06   0.34 ] | Goal: [ 0.037 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.231  0.121] | Goal: [ 0.114 -0.322  0.06 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    fps             | 459      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.026 -0.286  0.19 ] | Goal: [ 0.112 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.088  0.292] | Goal: [ 0.036 -0.318  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | -80.7       |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008770544 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | -0.036      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.82        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00803    |
# |    std                  | 1           |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.015 -0.189  0.109] | Goal: [ 0.038 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.035 -0.189  0.089] | Goal: [ 0.041 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.013 -0.252  0.121] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.184 -0.259  0.178] | Goal: [ 0.112 -0.315  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | -90         |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008229453 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.831       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.997       |
# |    value_loss           | 6.06        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.019 -0.212  0.228] | Goal: [ 0.177 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.193 -0.163  0.084] | Goal: [ 0.106 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.236 -0.217  0.064] | Goal: [ 0.179 -0.251  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008706415 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | -0.275      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.551       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00806    |
# |    std                  | 0.988       |
# |    value_loss           | 3.97        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.006 -0.184  0.111] | Goal: [-0.169 -0.248  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.114 -0.224  0.112] | Goal: [ 0.044 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.245  0.147] | Goal: [ 0.04  -0.245  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | -88.2       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010869514 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | -0.071      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.622       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00418    |
# |    std                  | 0.985       |
# |    value_loss           | 3.67        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.058 -0.197  0.041] | Goal: [ 0.18  -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.112 -0.193  0.009] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.042 -0.281  0.005] | Goal: [ 0.037 -0.324  0.025]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | -87.6       |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008651236 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | -0.00987    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00586    |
# |    std                  | 0.986       |
# |    value_loss           | 3.99        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.098 -0.233  0.226] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.124 -0.246  0.052] | Goal: [ 0.111 -0.319  0.025]
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 348       |
# |    ep_rew_mean          | -77.9     |
# | time/                   |           |
# |    fps                  | 398       |
# |    iterations           | 7         |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0098528 |
# |    clip_fraction        | 0.0401    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.61     |
# |    explained_variance   | 0.018     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.29      |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.00358  |
# |    std                  | 0.98      |
# |    value_loss           | 4.55      |
# ---------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.115 -0.18   0.016] | Goal: [ 0.11  -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.123  0.286] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 355         |
# |    ep_rew_mean          | -78.7       |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 8           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005587926 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.78        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00459    |
# |    std                  | 0.979       |
# |    value_loss           | 7.97        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.184  0.056] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.029 -0.176  0.1  ] | Goal: [-0.169 -0.318  0.03 ]
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 329        |
# |    ep_rew_mean          | -72.5      |
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 9          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00835384 |
# |    clip_fraction        | 0.0373     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.6       |
# |    explained_variance   | 0.044      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.21       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00516   |
# |    std                  | 0.982      |
# |    value_loss           | 5.75       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.066 -0.065  0.176] | Goal: [ 0.044 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.202 -0.158  0.061] | Goal: [ 0.112 -0.317  0.025]
# 📊 Step 20000 | ✅ Successes: 40 | ⏱️ Timeouts: 25
# 📈 Step 20000 | Reward (last 20000): -4361.0345 | 🎯 Goal: [ 0.041 -0.317  0.025],f🤖 EE Pos: [ 0.055 -0.165  0.1  ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -64.3       |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 10          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004353757 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.0842      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00395    |
# |    std                  | 0.982       |
# |    value_loss           | 9.38        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.088 -0.205  0.018] | Goal: [ 0.176 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.246  0.044] | Goal: [ 0.181 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.075 -0.228  0.214] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | -63.9        |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 11           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0077501205 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.0317       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.94         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00714     |
# |    std                  | 0.981        |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.239 -0.014] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 275          |
# |    ep_rew_mean          | -59          |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 12           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0059387237 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.0745       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.979        |
# |    value_loss           | 6.53         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.241  0.008] | Goal: [ 0.106 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.066 -0.21  -0.005] | Goal: [-0.169 -0.248  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | -58.9       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 13          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003009211 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.97        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.979       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.046 -0.197 -0.012] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.161  0.19 ] | Goal: [ 0.114 -0.318  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | -53.9        |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 14           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0067284014 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00622     |
# |    std                  | 0.976        |
# |    value_loss           | 6.68         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.056 -0.219 -0.007] | Goal: [ 0.041 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.158  0.161] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 235          |
# |    ep_rew_mean          | -47.3        |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 15           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0062657082 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.56        |
# |    explained_variance   | -0.0642      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.73         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00653     |
# |    std                  | 0.97         |
# |    value_loss           | 9.12         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.311  0.13 ] | Goal: [ 0.107 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.294  0.098] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.011 -0.25   0.096] | Goal: [ 0.18  -0.251  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 16           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0039905384 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.55        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.93         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00432     |
# |    std                  | 0.967        |
# |    value_loss           | 8.17         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.021 -0.192 -0.006] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | -40.4        |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 17           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0073949974 |
# |    clip_fraction        | 0.0804       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00618     |
# |    std                  | 0.963        |
# |    value_loss           | 6            |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.004 -0.228  0.021] | Goal: [ 0.106 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.162 -0.299  0.162] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | -38.6       |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 18          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005121366 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.86        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00331    |
# |    std                  | 0.96        |
# |    value_loss           | 8.06        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.257 -0.006] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.024 -0.268 -0.009] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | -37.8       |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 19          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005772156 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 0.955       |
# |    value_loss           | 9.83        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.284  0.219] | Goal: [-0.169 -0.318  0.03 ]
# 📊 Step 40000 | ✅ Successes: 119 | ⏱️ Timeouts: 44
# 📈 Step 40000 | Reward (last 20000): -3708.7941 | 🎯 Goal: [ 0.041 -0.246  0.06 ],f🤖 EE Pos: [ 0.185 -0.287  0.081]
# ⏱️ Timeout at Step 500 | EE: [ 0.166 -0.304  0.059] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -37.8        |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 20           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0054001147 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00414     |
# |    std                  | 0.952        |
# |    value_loss           | 5.97         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.231  0.273] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.004 -0.249 -0.01 ] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.066 -0.313  0.12 ] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | -37.7       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 21          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007993967 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00494    |
# |    std                  | 0.953       |
# |    value_loss           | 6.79        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.177 -0.221  0.124] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -36.3        |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 22           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0058074864 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.71         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00397     |
# |    std                  | 0.951        |
# |    value_loss           | 6.86         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.241  0.019] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | -32.5       |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 23          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006867269 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.36        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00564    |
# |    std                  | 0.948       |
# |    value_loss           | 7.03        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.111 -0.215  0.102] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.226 -0.005] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 190          |
# |    ep_rew_mean          | -32.6        |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 24           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0062878947 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.46        |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.73         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00438     |
# |    std                  | 0.948        |
# |    value_loss           | 7.48         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.217 -0.176  0.023] | Goal: [ 0.111 -0.316  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | -31.4        |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 25           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0064265984 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00634     |
# |    std                  | 0.945        |
# |    value_loss           | 5.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -27.9       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 26          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008154466 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00821    |
# |    std                  | 0.946       |
# |    value_loss           | 4.16        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.06 -0.21 -0.01] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.001 -0.324  0.036] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | -28.1       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 27          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004413822 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 0.943       |
# |    value_loss           | 9.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -20.6       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 28          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008293424 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00506    |
# |    std                  | 0.941       |
# |    value_loss           | 5.08        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.248  0.041] | Goal: [ 0.108 -0.324  0.025]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | -17.9        |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 29           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0055922493 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.04         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00682     |
# |    std                  | 0.936        |
# |    value_loss           | 7            |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.172 -0.202  0.222] | Goal: [-0.169 -0.318  0.03 ]
# 📊 Step 60000 | ✅ Successes: 249 | ⏱️ Timeouts: 57
# 📈 Step 60000 | Reward (last 20000): -3006.1395 | 🎯 Goal: [ 0.045 -0.254  0.06 ],f🤖 EE Pos: [ 0.152 -0.179 -0.005]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 30          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006182931 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 0.934       |
# |    value_loss           | 6.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 31          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006367068 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.0224      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 0.93        |
# |    value_loss           | 6.32        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.063 -0.26   0.008] | Goal: [-0.169 -0.318  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.107 -0.255 -0.007] | Goal: [-0.169 -0.318  0.03 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 32          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008456948 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.0102      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00541    |
# |    std                  | 0.929       |
# |    value_loss           | 4.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 33          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008839374 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00555    |
# |    std                  | 0.923       |
# |    value_loss           | 4.84        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | -12.8      |
# | time/                   |            |
# |    fps                  | 311        |
# |    iterations           | 34         |
# |    time_elapsed         | 223        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00727187 |
# |    clip_fraction        | 0.0481     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.33      |
# |    explained_variance   | 0.315      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.62       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00553   |
# |    std                  | 0.919      |
# |    value_loss           | 7.17       |
# ----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.19  -0.273  0.095] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.3         |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 35           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0073437844 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.32        |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00533     |
# |    std                  | 0.919        |
# |    value_loss           | 6.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.3         |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 36           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0046570743 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.31        |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00323     |
# |    std                  | 0.912        |
# |    value_loss           | 4.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.8         |
# |    ep_rew_mean          | -9.97        |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 37           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0055268765 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.28        |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 0.907        |
# |    value_loss           | 4.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.5        |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 38          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007641211 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.83        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00734    |
# |    std                  | 0.9         |
# |    value_loss           | 5.84        |
# -----------------------------------------
# ⏱️ Timeout at Step 500 | EE: [-0.152 -0.226 -0.007] | Goal: [-0.169 -0.318  0.03 ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.5         |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 39           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0077883736 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.22        |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00653     |
# |    std                  | 0.895        |
# |    value_loss           | 4.69         |
# ------------------------------------------
# 📊 Step 80000 | ✅ Successes: 444 | ⏱️ Timeouts: 61
# 📈 Step 80000 | Reward (last 20000): -2303.2102 | 🎯 Goal: [ 0.045 -0.249  0.06 ],f🤖 EE Pos: [-0.09  -0.242 -0.009]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -11.3        |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 40           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0059324224 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.22        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00474     |
# |    std                  | 0.898        |
# |    value_loss           | 4.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.3        |
# |    ep_rew_mean          | -9.68       |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 41          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006678926 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.21       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.893       |
# |    value_loss           | 3.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.6         |
# |    ep_rew_mean          | -9.97        |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 42           |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0066635874 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.19        |
# |    explained_variance   | -0.218       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00413     |
# |    std                  | 0.89         |
# |    value_loss           | 5.38         |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.005 -0.35   0.066] | Goal: [ 0.041 -0.253  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -10.9       |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 43          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008081926 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.0797      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00526    |
# |    std                  | 0.887       |
# |    value_loss           | 4.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.5         |
# |    ep_rew_mean          | -9.33        |
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 44           |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0075220596 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.17        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00363     |
# |    std                  | 0.886        |
# |    value_loss           | 2.7          |
# ------------------------------------------
# ⏱️ Timeout at Step 500 | EE: [ 0.171 -0.291  0.045] | Goal: [ 0.035 -0.247  0.06 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.3        |
# |    ep_rew_mean          | -9.87       |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 45          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005339823 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.0554      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00486    |
# |    std                  | 0.88        |
# |    value_loss           | 4.83        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -10.2        |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 46           |
# ...
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.361       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.99      |
# |    ep_rew_mean          | 1.88      |
# | time/                   |           |
# |    fps                  | 55        |
# |    iterations           | 247       |
# |    time_elapsed         | 9162      |
# |    total_timesteps      | 505856    |
# | train/                  |           |
# |    approx_kl            | 0.0219334 |
# |    clip_fraction        | 0.158     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.539     |
# |    explained_variance   | 0.164     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00403  |
# |    n_updates            | 2460      |
# |    policy_gradient_loss | -0.00655  |
# |    std                  | 0.36      |
# |    value_loss           | 0.0171    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.7          |
# |    ep_rew_mean          | 1.89         |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 248          |
# |    time_elapsed         | 9315         |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0103399735 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.59         |
# |    explained_variance   | 0.062        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00533     |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | -0.00801     |
# |    std                  | 0.357        |
# |    value_loss           | 0.0144       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.44         |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 249          |
# |    time_elapsed         | 9474         |
# |    total_timesteps      | 509952       |
# | train/                  |              |
# |    approx_kl            | 0.0099862255 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.642        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00133      |
# |    n_updates            | 2480         |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.355        |
# |    value_loss           | 0.0129       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 250         |
# |    time_elapsed         | 9637        |
# |    total_timesteps      | 512000      |
# | train/                  |             |
# |    approx_kl            | 0.013664896 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.686       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0082     |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.353       |
# |    value_loss           | 0.00978     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.74        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 251         |
# |    time_elapsed         | 9794        |
# |    total_timesteps      | 514048      |
# | train/                  |             |
# |    approx_kl            | 0.014690237 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.728       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00721    |
# |    n_updates            | 2500        |
# |    policy_gradient_loss | -0.00804    |
# |    std                  | 0.353       |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92        |
# |    ep_rew_mean          | 1.88        |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 252         |
# |    time_elapsed         | 9966        |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.010956379 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.769       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00562     |
# |    n_updates            | 2510        |
# |    policy_gradient_loss | -0.00609    |
# |    std                  | 0.352       |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 253         |
# |    time_elapsed         | 10129       |
# |    total_timesteps      | 518144      |
# | train/                  |             |
# |    approx_kl            | 0.018341381 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.817       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0103      |
# |    n_updates            | 2520        |
# |    policy_gradient_loss | -0.00366    |
# |    std                  | 0.35        |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# 📊 Step 520000 | ✅ Successes: 41458 | ⏱️ Timeouts: 81
# 📈 Step 520000 | Reward (last 20000): 13068.7725 | 🎯 Goal: [ 0.036 -0.246  0.06 ],f🤖 EE Pos: [ 0.    -0.207  0.15 ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.73        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 254         |
# |    time_elapsed         | 10298       |
# |    total_timesteps      | 520192      |
# | train/                  |             |
# |    approx_kl            | 0.014543166 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.863       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00738    |
# |    n_updates            | 2530        |
# |    policy_gradient_loss | -0.00633    |
# |    std                  | 0.349       |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.66       |
# |    ep_rew_mean          | 1.9        |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 255        |
# |    time_elapsed         | 10467      |
# |    total_timesteps      | 522240     |
# | train/                  |            |
# |    approx_kl            | 0.02016487 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.906      |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0241     |
# |    n_updates            | 2540       |
# |    policy_gradient_loss | 0.000761   |
# |    std                  | 0.347      |
# |    value_loss           | 0.00922    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41        |
# |    ep_rew_mean          | 1.91        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 256         |
# |    time_elapsed         | 10643       |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.008526639 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.943       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0088     |
# |    n_updates            | 2550        |
# |    policy_gradient_loss | 0.00123     |
# |    std                  | 0.345       |
# |    value_loss           | 0.00925     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 257         |
# |    time_elapsed         | 10827       |
# |    total_timesteps      | 526336      |
# | train/                  |             |
# |    approx_kl            | 0.010584638 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.984       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0011      |
# |    n_updates            | 2560        |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 0.342       |
# |    value_loss           | 0.0088      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27        |
# |    ep_rew_mean          | 1.91        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 258         |
# |    time_elapsed         | 11004       |
# |    total_timesteps      | 528384      |
# | train/                  |             |
# |    approx_kl            | 0.012665943 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.03        |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00168    |
# |    n_updates            | 2570        |
# |    policy_gradient_loss | 0.000111    |
# |    std                  | 0.343       |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.47      |
# |    ep_rew_mean          | 1.9       |
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 259       |
# |    time_elapsed         | 11183     |
# |    total_timesteps      | 530432    |
# | train/                  |           |
# |    approx_kl            | 0.0161567 |
# |    clip_fraction        | 0.193     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.06      |
# |    explained_variance   | 0.355     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.014     |
# |    n_updates            | 2580      |
# |    policy_gradient_loss | 0.000524  |
# |    std                  | 0.341     |
# |    value_loss           | 0.0065    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.61        |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 260         |
# |    time_elapsed         | 11376       |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.011302559 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.1         |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00561     |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.00205    |
# |    std                  | 0.341       |
# |    value_loss           | 0.00749     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.26       |
# |    ep_rew_mean          | 1.91       |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 261        |
# |    time_elapsed         | 11576      |
# |    total_timesteps      | 534528     |
# | train/                  |            |
# |    approx_kl            | 0.01430263 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.14       |
# |    explained_variance   | 0.311      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00605   |
# |    n_updates            | 2600       |
# |    policy_gradient_loss | -0.00453   |
# |    std                  | 0.339      |
# |    value_loss           | 0.00624    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36        |
# |    ep_rew_mean          | 1.91        |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 262         |
# |    time_elapsed         | 11752       |
# |    total_timesteps      | 536576      |
# | train/                  |             |
# |    approx_kl            | 0.015804157 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.17        |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00652     |
# |    n_updates            | 2610        |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.339       |
# |    value_loss           | 0.00649     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.54        |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 263         |
# |    time_elapsed         | 11934       |
# |    total_timesteps      | 538624      |
# | train/                  |             |
# |    approx_kl            | 0.014913321 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.21        |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00387    |
# |    n_updates            | 2620        |
# |    policy_gradient_loss | -0.00555    |
# |    std                  | 0.337       |
# |    value_loss           | 0.00697     |
# -----------------------------------------

# %%
model.save("ppo_uarm")
1 000 000
