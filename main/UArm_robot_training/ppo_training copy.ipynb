# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)},f🤖 EE Pos: {np.round(ef_pos, 3)} ")
            self.cumulative_reward = 0

        return True

# %%
from stable_baselines3 import PPO
from env import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=1
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=1_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_pos_final_30")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkUsing cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04390762 -0.32124802  0.06      ]
# 🎉 Goal reached! EE: [ 0.063 -0.316  0.07 ] | Goal: [ 0.044 -0.321  0.06 ] | Reward: -0.0221
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10544503 -0.25465036  0.06      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04086447 -0.32363899  0.06      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11148211 -0.25302931  0.025     ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | -99.8    |
# | time/              |          |
# |    fps             | 507      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# 🎉 Goal reached! EE: [ 0.098 -0.264  0.03 ] | Goal: [ 0.111 -0.253  0.025] | Reward: -0.0188
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17986938 -0.24742816  0.06      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.0379849  -0.31961791  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007460274 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | -0.00298    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00727    |
# |    std                  | 0.996       |
# |    value_loss           | 11.2        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04077504 -0.24923828  0.06      ]
# 🎉 Goal reached! EE: [ 0.029 -0.233  0.05 ] | Goal: [ 0.041 -0.249  0.06 ] | Reward: -0.0224
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.164 -0.266  0.027] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0196
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11217155 -0.24891094  0.025     ]
# 🎉 Goal reached! EE: [ 0.135 -0.251  0.044] | Goal: [ 0.112 -0.249  0.025] | Reward: -0.03
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008038633 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | -0.212      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00753    |
# |    std                  | 0.991       |
# |    value_loss           | 8.77        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03654544 -0.31589528  0.06      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04468355 -0.25166915  0.025     ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 429          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0069545186 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | -0.238       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00544     |
# |    std                  | 0.988        |
# |    value_loss           | 5.31         |
# ------------------------------------------
# 🎉 Goal reached! EE: [ 0.031 -0.232  0.037] | Goal: [ 0.045 -0.252  0.025] | Reward: -0.0266
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.0383147  -0.32252752  0.06      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10933013 -0.2545815   0.025     ]
# 🎉 Goal reached! EE: [ 0.116 -0.268  0.033] | Goal: [ 0.109 -0.255  0.025] | Reward: -0.017
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04243908 -0.24639408  0.025     ]
# 🎉 Goal reached! EE: [ 0.036 -0.239  0.028] | Goal: [ 0.042 -0.246  0.025] | Reward: -0.0109
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10590264 -0.31608279  0.06      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | -99.3        |
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0083872825 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.62        |
# |    explained_variance   | 0.0435       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00507     |
# |    std                  | 0.986        |
# |    value_loss           | 3.81         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10696741 -0.24624682  0.025     ]
# 🎉 Goal reached! EE: [ 0.093 -0.235  0.011] | Goal: [ 0.107 -0.246  0.025] | Reward: -0.0227
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18361346 -0.25374247  0.025     ]
# 🎉 Goal reached! EE: [ 0.17  -0.242  0.037] | Goal: [ 0.184 -0.254  0.025] | Reward: -0.0214
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.172 -0.244  0.004] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.026
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03555863 -0.31538095  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | -97.2       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010463448 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00336    |
# |    std                  | 0.981       |
# |    value_loss           | 4.6         |
# -----------------------------------------
# 🎉 Goal reached! EE: [-0.191 -0.197  0.028] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0296
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03592002 -0.31573221  0.06      ]
# 🎉 Goal reached! EE: [ 0.027 -0.296  0.075] | Goal: [ 0.036 -0.316  0.06 ] | Reward: -0.0266
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03695681 -0.24816561  0.06      ]
# 🎉 Goal reached! EE: [ 0.042 -0.255  0.067] | Goal: [ 0.037 -0.248  0.06 ] | Reward: -0.011
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18433363 -0.24894387  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18253455 -0.25468334  0.025     ]
# 🎉 Goal reached! EE: [ 0.173 -0.233  0.023] | Goal: [ 0.183 -0.255  0.025] | Reward: -0.0238
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04075219 -0.24741181  0.06      ]
# 🎉 Goal reached! EE: [ 0.033 -0.246  0.058] | Goal: [ 0.041 -0.247  0.06 ] | Reward: -0.008
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10993133 -0.3165694   0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11253551 -0.31913732  0.06      ]
# 🎉 Goal reached! EE: [ 0.111 -0.3    0.08 ] | Goal: [ 0.113 -0.319  0.06 ] | Reward: -0.0277
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | -86.8        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 7            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0072490685 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | -0.0404      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0048      |
# |    std                  | 0.981        |
# |    value_loss           | 4.35         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.181 -0.16   0.025] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0216
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03944044 -0.25249804  0.06      ]
# 🎉 Goal reached! EE: [ 0.057 -0.27   0.067] | Goal: [ 0.039 -0.252  0.06 ] | Reward: -0.0262
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17617918 -0.24626974  0.025     ]
# 🎉 Goal reached! EE: [ 0.163 -0.259  0.011] | Goal: [ 0.176 -0.246  0.025] | Reward: -0.0225
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11002179 -0.25340545  0.025     ]
# 🎉 Goal reached! EE: [ 0.115 -0.236  0.038] | Goal: [ 0.11  -0.253  0.025] | Reward: -0.022
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.164 -0.178  0.033] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0065
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11255115 -0.31785693  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1820939  -0.25260075  0.025     ]
# 🎉 Goal reached! EE: [ 0.19  -0.263  0.048] | Goal: [ 0.182 -0.253  0.025] | Reward: -0.0264
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1080705  -0.32197103  0.025     ]
# 🎉 Goal reached! EE: [ 0.087 -0.317  0.031] | Goal: [ 0.108 -0.322  0.025] | Reward: -0.0225
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11450882 -0.31781125  0.06      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | -78.3        |
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 8            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0071153096 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.63         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00547     |
# |    std                  | 0.979        |
# |    value_loss           | 7.77         |
# ------------------------------------------
# 🎉 Goal reached! EE: [ 0.108 -0.327  0.055] | Goal: [ 0.115 -0.318  0.06 ] | Reward: -0.012
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10870029 -0.31620568  0.06      ]
# 🎉 Goal reached! EE: [ 0.11  -0.306  0.086] | Goal: [ 0.109 -0.316  0.06 ] | Reward: -0.0275
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11073003 -0.25445269  0.025     ]
# 🎉 Goal reached! EE: [ 0.096 -0.234  0.022] | Goal: [ 0.111 -0.254  0.025] | Reward: -0.0251
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17669931 -0.2492964   0.06      ]
# 🎉 Goal reached! EE: [ 0.194 -0.253  0.076] | Goal: [ 0.177 -0.249  0.06 ] | Reward: -0.0237
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18002004 -0.2454176   0.06      ]
# 🎉 Goal reached! EE: [ 0.196 -0.253  0.049] | Goal: [ 0.18  -0.245  0.06 ] | Reward: -0.0209
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.0397603  -0.31737255  0.06      ]
# 🎉 Goal reached! EE: [ 0.026 -0.327  0.047] | Goal: [ 0.04  -0.317  0.06 ] | Reward: -0.0208
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11003743 -0.32162055  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.0367677  -0.24880578  0.025     ]
# 🎉 Goal reached! EE: [ 0.043 -0.231  0.004] | Goal: [ 0.037 -0.249  0.025] | Reward: -0.0283
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | -73.9        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 9            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0090350155 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.045        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.84         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00933     |
# |    std                  | 0.979        |
# |    value_loss           | 8.38         |
# ------------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.161 -0.241  0.003] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.029
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04190218 -0.3232835   0.025     ]
# 🎉 Goal reached! EE: [ 0.022 -0.301  0.02 ] | Goal: [ 0.042 -0.323  0.025] | Reward: -0.0298
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04259714 -0.31543483  0.025     ]
# 🎉 Goal reached! EE: [ 0.054 -0.311  0.021] | Goal: [ 0.043 -0.315  0.025] | Reward: -0.0128
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03826364 -0.25241644  0.06      ]
# 🎉 Goal reached! EE: [ 0.037 -0.264  0.057] | Goal: [ 0.038 -0.252  0.06 ] | Reward: -0.0124
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10664142 -0.25002674  0.025     ]
# 🎉 Goal reached! EE: [ 0.097 -0.239  0.024] | Goal: [ 0.107 -0.25   0.025] | Reward: -0.0142
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.155 -0.193  0.012] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0278
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18007293 -0.24627379  0.025     ]
# 🎉 Goal reached! EE: [ 0.176 -0.238  0.027] | Goal: [ 0.18  -0.246  0.025] | Reward: -0.0095
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11473291 -0.24545326  0.06      ]
# 🎉 Goal reached! EE: [ 0.091 -0.25   0.061] | Goal: [ 0.115 -0.245  0.06 ] | Reward: -0.024
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10607664 -0.31538954  0.06      ]
# 🎉 Goal reached! EE: [ 0.123 -0.32   0.06 ] | Goal: [ 0.106 -0.315  0.06 ] | Reward: -0.0176
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 📊 Step 20000 | ✅ Successes: 40 | ⏱️ Timeouts: 26
# 📈 Step 20000 | Reward (last 20000): -4435.3532 | 🎯 Goal: [-0.169 -0.248  0.03 ],f🤖 EE Pos: [ 0.143 -0.311  0.064]
# 🎉 Goal reached! EE: [-0.176 -0.228  0.02 ] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.023
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18454979 -0.25408556  0.025     ]
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 303          |
# |    ep_rew_mean          | -67          |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 10           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0081938505 |
# |    clip_fraction        | 0.0881       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.0551       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.52         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00841     |
# |    std                  | 0.979        |
# |    value_loss           | 8.33         |
# ------------------------------------------
# 🎉 Goal reached! EE: [ 0.186 -0.231  0.041] | Goal: [ 0.185 -0.254  0.025] | Reward: -0.0284
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.168 -0.236  0.002] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0299
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.144 -0.177  0.045] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.03
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03759131 -0.2470955   0.06      ]
# 🎉 Goal reached! EE: [ 0.057 -0.24   0.075] | Goal: [ 0.038 -0.247  0.06 ] | Reward: -0.0254
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04054091 -0.31763382  0.06      ]
# 🎉 Goal reached! EE: [ 0.043 -0.345  0.055] | Goal: [ 0.041 -0.318  0.06 ] | Reward: -0.0284
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# Goal position set to: [ 0.04022281 -0.24732799  0.06      ]No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link
# 🎉 Goal reached! EE: [ 0.054 -0.232  0.042] | Goal: [ 0.04  -0.247  0.06 ] | Reward: -0.0274
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.177 -0.251  0.038] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0112
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.159 -0.257  0.014] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0215
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10620928 -0.24531063  0.06      ]
# 🎉 Goal reached! EE: [ 0.121 -0.236  0.061] | Goal: [ 0.106 -0.245  0.06 ] | Reward: -0.0179
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04197682 -0.2541892   0.025     ]
# 🎉 Goal reached! EE: [ 0.064 -0.235  0.021] | Goal: [ 0.042 -0.254  0.025] | Reward: -0.0299
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04333019 -0.25376714  0.06      ]
# 🎉 Goal reached! EE: [ 0.05  -0.231  0.073] | Goal: [ 0.043 -0.254  0.06 ] | Reward: -0.0266
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04443935 -0.31891724  0.06      ]
# 🎉 Goal reached! EE: [ 0.069 -0.329  0.05 ] | Goal: [ 0.044 -0.319  0.06 ] | Reward: -0.0279
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11440734 -0.25392382  0.025     ]
# 🎉 Goal reached! EE: [ 0.093 -0.256  0.016] | Goal: [ 0.114 -0.254  0.025] | Reward: -0.0229
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10774823 -0.25121857  0.06      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | -60         |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 11          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008497512 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.0279      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.35        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00804    |
# |    std                  | 0.977       |
# |    value_loss           | 10.2        |
# -----------------------------------------
# 🎉 Goal reached! EE: [ 0.125 -0.268  0.043] | Goal: [ 0.108 -0.251  0.06 ] | Reward: -0.0292
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10602649 -0.31525658  0.06      ]
# 🎉 Goal reached! EE: [ 0.097 -0.292  0.058] | Goal: [ 0.106 -0.315  0.06 ] | Reward: -0.0253
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04420094 -0.2480413   0.06      ]
# 🎉 Goal reached! EE: [ 0.036 -0.27   0.047] | Goal: [ 0.044 -0.248  0.06 ] | Reward: -0.0265
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03618441 -0.25020851  0.025     ]
# 🎉 Goal reached! EE: [ 0.038 -0.255  0.03 ] | Goal: [ 0.036 -0.25   0.025] | Reward: -0.007
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.168 -0.202  0.044] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0288
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03866094 -0.31901271  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04241439 -0.31545461  0.06      ]
# 🎉 Goal reached! EE: [ 0.037 -0.326  0.07 ] | Goal: [ 0.042 -0.315  0.06 ] | Reward: -0.0159
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04156074 -0.25375523  0.06      ]
# 🎉 Goal reached! EE: [ 0.06  -0.249  0.064] | Goal: [ 0.042 -0.254  0.06 ] | Reward: -0.0193
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18186764 -0.25319911  0.025     ]
# 🎉 Goal reached! EE: [ 0.167 -0.232  0.014] | Goal: [ 0.182 -0.253  0.025] | Reward: -0.0284
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03997683 -0.31584727  0.06      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | -57.9       |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 12          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010224169 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.0604      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00708    |
# |    std                  | 0.975       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# 🎉 Goal reached! EE: [ 0.029 -0.293  0.063] | Goal: [ 0.04  -0.316  0.06 ] | Reward: -0.0257
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03875266 -0.31592106  0.025     ]
# 🎉 Goal reached! EE: [ 0.03  -0.322  0.026] | Goal: [ 0.039 -0.316  0.025] | Reward: -0.0109
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10680049 -0.3238809   0.06      ]
# 🎉 Goal reached! EE: [ 0.107 -0.321  0.073] | Goal: [ 0.107 -0.324  0.06 ] | Reward: -0.0134
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10500261 -0.2528846   0.06      ]
# 🎉 Goal reached! EE: [ 0.084 -0.245  0.062] | Goal: [ 0.105 -0.253  0.06 ] | Reward: -0.0226
# ...
# camera_link🎉 Goal reached! EE: [ 0.044 -0.262  0.025] | Goal: [ 0.04  -0.251  0.025] | Reward: -0.0121
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11249086 -0.32347153  0.06      ]
# 🎉 Goal reached! EE: [ 0.095 -0.337  0.064] | Goal: [ 0.112 -0.323  0.06 ] | Reward: -0.0225
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.1084451  -0.31742002  0.06      ]
# 🎉 Goal reached! EE: [ 0.095 -0.316  0.056] | Goal: [ 0.108 -0.317  0.06 ] | Reward: -0.0139
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.19  -0.17   0.019] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0248
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04184211 -0.2458344   0.025     ]
# 🎉 Goal reached! EE: [ 0.02  -0.258  0.022] | Goal: [ 0.042 -0.246  0.025] | Reward: -0.025
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10973481 -0.24737419  0.025     ]
# 🎉 Goal reached! EE: [ 0.114 -0.23   0.022] | Goal: [ 0.11  -0.247  0.025] | Reward: -0.0179
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.178 -0.246  0.035] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0099
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.042851   -0.32253039  0.06      ]
# 🎉 Goal reached! EE: [ 0.045 -0.331  0.048] | Goal: [ 0.043 -0.323  0.06 ] | Reward: -0.0148
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04025032 -0.31626713  0.06      ]
# 🎉 Goal reached! EE: [ 0.055 -0.336  0.045] | Goal: [ 0.04  -0.316  0.06 ] | Reward: -0.0283
# Goal position set to: [ 0.11482708 -0.24613844  0.025     ]
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_link🎉 Goal reached! EE: [ 0.124 -0.229  0.003] | Goal: [ 0.115 -0.246  0.025] | Reward: -0.0295
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10665619 -0.32407134  0.06      ]
# 🎉 Goal reached! EE: [ 0.109 -0.305  0.037] | Goal: [ 0.107 -0.324  0.06 ] | Reward: -0.0298
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03630334 -0.24828588  0.06      ]
# 🎉 Goal reached! EE: [ 0.052 -0.256  0.06 ] | Goal: [ 0.036 -0.248  0.06 ] | Reward: -0.0175
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.9        |
# |    ep_rew_mean          | -1.33       |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 112         |
# |    time_elapsed         | 1005        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.004213724 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.992       |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00374    |
# |    std                  | 0.663       |
# |    value_loss           | 2.36        |
# -----------------------------------------
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.163 -0.191  0.013] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0221
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.03656214 -0.25472191  0.025     ]
# 🎉 Goal reached! EE: [ 0.034 -0.274  0.031] | Goal: [ 0.037 -0.255  0.025] | Reward: -0.02
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04145949 -0.32111     0.025     ]
# 🎉 Goal reached! EE: [ 0.042 -0.324  0.041] | Goal: [ 0.041 -0.321  0.025] | Reward: -0.0164
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.142 -0.174  0.028] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0275
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.165 -0.271  0.016] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0277
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.176 -0.296  0.048] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0293
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.11265155 -0.2467665   0.06      ]
# 🎉 Goal reached! EE: [ 0.137 -0.247  0.059] | Goal: [ 0.113 -0.247  0.06 ] | Reward: -0.0242
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04264218 -0.31577392  0.025     ]
# 🎉 Goal reached! EE: [ 0.059 -0.308  0.016] | Goal: [ 0.043 -0.316  0.025] | Reward: -0.0202
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10510948 -0.25017129  0.06      ]
# 🎉 Goal reached! EE: [ 0.104 -0.256  0.078] | Goal: [ 0.105 -0.25   0.06 ] | Reward: -0.0192
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.17758668 -0.2492494   0.06      ]
# 🎉 Goal reached! EE: [ 0.176 -0.251  0.037] | Goal: [ 0.178 -0.249  0.06 ] | Reward: -0.0231
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04056769 -0.31935035  0.025     ]
# 🎉 Goal reached! EE: [ 0.065 -0.315  0.031] | Goal: [ 0.041 -0.319  0.025] | Reward: -0.0251
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.167 -0.191  0.008] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0257
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10846832 -0.24716756  0.025     ]
# 🎉 Goal reached! EE: [ 0.107 -0.246  0.004] | Goal: [ 0.108 -0.247  0.025] | Reward: -0.0212
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10678163 -0.31820832  0.06      ]
# 🎉 Goal reached! EE: [ 0.109 -0.331  0.057] | Goal: [ 0.107 -0.318  0.06 ] | Reward: -0.0137
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.24760068  0.03      ]
# 🎉 Goal reached! EE: [-0.157 -0.259  0.022] | Goal: [-0.169 -0.248  0.03 ] | Reward: -0.0184
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18173366 -0.24584901  0.025     ]
# 🎉 Goal reached! EE: [ 0.193 -0.228  0.023] | Goal: [ 0.182 -0.246  0.025] | Reward: -0.0207
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.10931939 -0.25074312  0.06      ]
# 🎉 Goal reached! EE: [ 0.1   -0.236  0.049] | Goal: [ 0.109 -0.251  0.06 ] | Reward: -0.0204
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.04485474 -0.31858779  0.06      ]
# 🎉 Goal reached! EE: [ 0.059 -0.321  0.084] | Goal: [ 0.045 -0.319  0.06 ] | Reward: -0.0284
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18417687 -0.25041672  0.025     ]
# 🎉 Goal reached! EE: [ 0.18  -0.244  0.02 ] | Goal: [ 0.184 -0.25   0.025] | Reward: -0.0094
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [ 0.18349038 -0.25307625  0.06      ]
# 🎉 Goal reached! EE: [ 0.197 -0.254  0.062] | Goal: [ 0.183 -0.253  0.06 ] | Reward: -0.0139
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]
# 🎉 Goal reached! EE: [-0.159 -0.293  0.034] | Goal: [-0.169 -0.318  0.03 ] | Reward: -0.0269
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# Goal position set to: [ 0.11263003 -0.32407805  0.025     ]
# camera_link🎉 Goal reached! EE: [ 0.122 -0.316  0.041] | Goal: [ 0.113 -0.324  0.025] | Reward: -0.0203
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.186 -0.177  0.018] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0202
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.17760068  0.03      ]
# 🎉 Goal reached! EE: [-0.159 -0.178  0.03 ] | Goal: [-0.169 -0.178  0.03 ] | Reward: -0.0108
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# camera_linkGoal position set to: [-0.16939274 -0.31760068  0.03      ]

# %%
model.save("ppo_uarm")
1 000 000
