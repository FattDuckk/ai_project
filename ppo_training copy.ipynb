# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import datetime


class RewardAndGoalLoggingCallback(BaseCallback):
    def __init__(self, log_interval=20000, verbose=0):
        super().__init__(verbose)
        self.log_interval = log_interval
        self.cumulative_reward = 0
        self.step_counter = 0

    def _on_step(self):
        reward = self.locals["rewards"][0]
        self.cumulative_reward += reward
        self.step_counter += 1

        if self.step_counter % self.log_interval == 0:
            # Get the goal_pos from the environment (VecEnv-safe)
            curent_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            goal_pos = self.training_env.get_attr("goal_pos")[0]
            ef_pos = self.training_env.get_attr("robot")[0].get_joint_obs()["ee_pos"]
            print(f"time: {curent_time} 📈 Step {self.num_timesteps} | Reward (last {self.log_interval}): {round(self.cumulative_reward, 4)} | 🎯 Goal: {np.round(goal_pos, 3)}")
            self.cumulative_reward = 0
            

        return True

# %%
from stable_baselines3 import PPO
from env import UArmEnv

# Create environment and model
env = UArmEnv(render=False)
model = PPO(
    "MlpPolicy",
    env,
    ent_coef=0.005,        # Encourages broader exploration without overwhelming reward
    n_steps=2048,          # Longer rollout → better credit assignment
    batch_size=256,        # Good match for long rollouts
    gae_lambda=0.95,       # Slightly longer-term reward tracking
    gamma=0.99,            # Standard long-term discount
    verbose=0
)

# Add logging callback
reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)

# Train with logging
model.learn(total_timesteps=2_000_000, callback=reward_logger)

env.close()

model.save("ppo_uarm_overtrained")
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/fatduck/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ⏱️ Timeout at Step 500 | EE: [ 0.024 -0.159  0.111] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.009 -0.217 -0.003] | Goal: [ 0.035 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.141  0.064] | Goal: [ 0.038 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.218  0.161] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.055  0.347] | Goal: [ 0.041 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.05  -0.07   0.179] | Goal: [ 0.115 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.22  -0.007] | Goal: [ 0.107 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.055 -0.1    0.242] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.152  0.242] | Goal: [ 0.042 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.152  0.188] | Goal: [ 0.107 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.197  0.06 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.083 -0.144  0.13 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.102 -0.126  0.116] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.011 -0.202  0.295] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.065 -0.201 -0.006] | Goal: [ 0.115 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.056 -0.188 -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.179 -0.167  0.047] | Goal: [ 0.037 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.19  -0.012] | Goal: [ 0.037 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.242  0.011] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.187 -0.006] | Goal: [ 0.042 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.01  -0.042  0.342] | Goal: [ 0.108 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.157  0.114] | Goal: [ 0.113 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.25  -0.216  0.133] | Goal: [ 0.112 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.075 -0.22   0.008] | Goal: [ 0.039 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.085 -0.137  0.107] | Goal: [ 0.107 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.13  -0.182  0.221] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.046  0.21 ] | Goal: [ 0.111 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.092 -0.101  0.132] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.223 -0.157  0.064] | Goal: [ 0.107 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.206 -0.194  0.173] | Goal: [ 0.11  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.187 -0.191  0.195] | Goal: [ 0.039 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.152 -0.152  0.276] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.014 -0.182  0.109] | Goal: [ 0.111 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.137 -0.214  0.229] | Goal: [ 0.044 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.114 -0.174 -0.008] | Goal: [ 0.109 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.147  0.119] | Goal: [ 0.107 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.218  0.21 ] | Goal: [ 0.112 -0.317  0.06 ]
# 📊 Step 20000 | ✅ Successes: 6 | ⏱️ Timeouts: 37
# time: 2025-06-19 23:16:18 📈 Step 20000 | Reward (last 20000): -5350.1505 | 🎯 Goal: [ 0.114 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.135 -0.095  0.106] | Goal: [ 0.114 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.041 -0.136  0.128] | Goal: [ 0.112 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [0.    0.029 0.317] | Goal: [ 0.041 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.182 -0.   ] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.072 -0.133  0.131] | Goal: [ 0.108 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [0.034 0.048 0.308] | Goal: [ 0.106 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.004 -0.007  0.256] | Goal: [ 0.105 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.127 -0.172  0.091] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.061 -0.24  -0.006] | Goal: [ 0.04  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.129 -0.174  0.215] | Goal: [ 0.044 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.041 -0.207  0.143] | Goal: [ 0.044 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.037 -0.201 -0.011] | Goal: [ 0.037 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.183 -0.138  0.276] | Goal: [ 0.112 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.186 -0.242  0.201] | Goal: [ 0.042 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.203 -0.262  0.123] | Goal: [ 0.109 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.118 -0.183  0.051] | Goal: [ 0.038 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.104 -0.16   0.024] | Goal: [ 0.036 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.152 -0.112 -0.013] | Goal: [ 0.04 -0.32  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.041 -0.223  0.004] | Goal: [ 0.044 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.098 -0.098  0.131] | Goal: [ 0.114 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.203  0.017] | Goal: [ 0.107 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.191  0.022] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.023 -0.263 -0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.009 -0.21   0.118] | Goal: [ 0.113 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.186  0.013] | Goal: [ 0.037 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.274 -0.22   0.083] | Goal: [ 0.041 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.119 -0.181 -0.006] | Goal: [ 0.105 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.218  0.119] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.144 -0.173 -0.003] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.214  0.108] | Goal: [ 0.107 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.209 -0.009] | Goal: [ 0.039 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.141 -0.149  0.172] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.016 -0.194  0.034] | Goal: [ 0.114 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.178 -0.137  0.161] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.208 -0.008] | Goal: [ 0.113 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.166 -0.235  0.146] | Goal: [ 0.113 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.107 -0.17  -0.009] | Goal: [ 0.042 -0.247  0.06 ]
# 📊 Step 40000 | ✅ Successes: 5 | ⏱️ Timeouts: 37
# time: 2025-06-19 23:17:02 📈 Step 40000 | Reward (last 20000): -4970.2563 | 🎯 Goal: [ 0.038 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.115 -0.171  0.054] | Goal: [ 0.038 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.129 -0.3    0.153] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.13  -0.008] | Goal: [ 0.042 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.13   0.118] | Goal: [ 0.113 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.002 -0.093  0.286] | Goal: [ 0.038 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.039 -0.031  0.327] | Goal: [ 0.043 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.111 -0.211  0.256] | Goal: [ 0.043 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.187 -0.139  0.026] | Goal: [ 0.109 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.126 -0.142 -0.001] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.193 -0.006] | Goal: [ 0.041 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.172  0.113] | Goal: [ 0.039 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.023 -0.216 -0.008] | Goal: [ 0.044 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.064 -0.143  0.136] | Goal: [ 0.043 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.019  0.331] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.039 -0.207 -0.012] | Goal: [ 0.04  -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.172  0.034] | Goal: [ 0.113 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.162 -0.261  0.028] | Goal: [ 0.045 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.114 -0.152  0.008] | Goal: [ 0.111 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.071 -0.207 -0.004] | Goal: [ 0.039 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.006 -0.007  0.304] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.176  0.131] | Goal: [ 0.039 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.107 -0.259  0.081] | Goal: [ 0.107 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.009 -0.201 -0.008] | Goal: [ 0.113 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.147  0.062] | Goal: [ 0.039 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.003 -0.183  0.104] | Goal: [ 0.11  -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.148 -0.121  0.131] | Goal: [ 0.039 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.215  0.047] | Goal: [ 0.041 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.162 -0.008] | Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.15  -0.146 -0.005] | Goal: [ 0.106 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.129 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.074 -0.187  0.05 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.087 -0.293  0.057] | Goal: [ 0.107 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.223 -0.006] | Goal: [ 0.111 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.203 -0.009] | Goal: [ 0.106 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.065 -0.346  0.078] | Goal: [ 0.106 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.064 -0.253 -0.01 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.107 -0.184 -0.009] | Goal: [ 0.113 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.156 -0.009] | Goal: [ 0.045 -0.252  0.06 ]
# 📊 Step 60000 | ✅ Successes: 5 | ⏱️ Timeouts: 38
# time: 2025-06-19 23:17:44 📈 Step 60000 | Reward (last 20000): -4759.4662 | 🎯 Goal: [ 0.113 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.041 -0.132  0.139] | Goal: [ 0.113 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.051 -0.219  0.029] | Goal: [ 0.113 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.018 -0.201 -0.014] | Goal: [ 0.037 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.076 -0.201  0.005] | Goal: [ 0.115 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [0.    0.008 0.345] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.152 -0.114  0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.182 -0.121  0.027] | Goal: [ 0.11  -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.106 -0.131  0.158] | Goal: [ 0.114 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.1   -0.207  0.046] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.081 -0.277  0.019] | Goal: [ 0.036 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.02  -0.026  0.327] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.108 -0.181 -0.004] | Goal: [ 0.111 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.043 -0.207 -0.004] | Goal: [ 0.043 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.117 -0.306  0.072] | Goal: [ 0.04  -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.176  0.179] | Goal: [ 0.042 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.193 -0.009] | Goal: [ 0.106 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.05  -0.153  0.121] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.219  0.189] | Goal: [ 0.044 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.069 -0.183 -0.009] | Goal: [ 0.113 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.114  0.139] | Goal: [ 0.109 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.122 -0.011] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.203  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.128 -0.164  0.113] | Goal: [ 0.112 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.164 -0.124  0.098] | Goal: [ 0.038 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.166 -0.224 -0.008] | Goal: [ 0.039 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.124 -0.143 -0.007] | Goal: [ 0.109 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.026 -0.196 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.137 -0.007] | Goal: [ 0.108 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.216 -0.24   0.08 ] | Goal: [ 0.109 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.076 -0.264  0.238] | Goal: [ 0.04  -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.197 -0.152  0.104] | Goal: [ 0.037 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.049 -0.191  0.007] | Goal: [ 0.106 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.106  0.251] | Goal: [ 0.044 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.212 -0.005] | Goal: [ 0.041 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.104 -0.287  0.067] | Goal: [ 0.036 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.062 -0.104  0.171] | Goal: [ 0.106 -0.318  0.025]
# 📊 Step 80000 | ✅ Successes: 6 | ⏱️ Timeouts: 36
# time: 2025-06-19 23:18:26 📈 Step 80000 | Reward (last 20000): -4855.2201 | 🎯 Goal: [ 0.036 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.201 -0.006] | Goal: [ 0.036 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.109 -0.109  0.179] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.069 -0.134  0.204] | Goal: [ 0.109 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.03  -0.189  0.075] | Goal: [ 0.041 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.095 -0.182 -0.007] | Goal: [ 0.114 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.019 -0.255 -0.005] | Goal: [ 0.035 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.15  -0.171 -0.008] | Goal: [ 0.036 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.255 -0.236  0.061] | Goal: [ 0.105 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.189  0.26 ] | Goal: [ 0.037 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.113 -0.178 -0.006] | Goal: [ 0.044 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.03  -0.188  0.004] | Goal: [ 0.043 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.074 -0.179  0.011] | Goal: [ 0.042 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.241 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.054 -0.171  0.077] | Goal: [ 0.11  -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.089 -0.179  0.02 ] | Goal: [ 0.038 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.148 -0.125  0.047] | Goal: [ 0.11  -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.185 -0.003] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.192 -0.137 -0.004] | Goal: [ 0.11  -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.161 -0.006] | Goal: [ 0.112 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.215 -0.011] | Goal: [ 0.105 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.155  0.064] | Goal: [ 0.112 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.24  -0.005] | Goal: [ 0.043 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.016 -0.187  0.097] | Goal: [ 0.035 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.138 -0.143 -0.008] | Goal: [ 0.043 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.214  0.113] | Goal: [ 0.041 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.142 -0.204 -0.008] | Goal: [ 0.114 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.207 -0.005] | Goal: [ 0.106 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.085 -0.194 -0.004] | Goal: [ 0.114 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.076 -0.167  0.079] | Goal: [ 0.043 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.157 -0.01 ] | Goal: [ 0.045 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.177  0.145] | Goal: [ 0.108 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.201 -0.206 -0.006] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.208 -0.003] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 100000 | ✅ Successes: 20 | ⏱️ Timeouts: 33
# time: 2025-06-19 23:19:11 📈 Step 100000 | Reward (last 20000): -4759.9356 | 🎯 Goal: [ 0.11  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.017 -0.21  -0.004] | Goal: [ 0.11  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.267 -0.208  0.113] | Goal: [ 0.113 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.069 -0.207  0.18 ] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.127 -0.172  0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.12  -0.155  0.067] | Goal: [ 0.107 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.074 -0.258  0.003] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.132 -0.177 -0.007] | Goal: [ 0.039 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.212 -0.005] | Goal: [ 0.11  -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.075 -0.257  0.066] | Goal: [ 0.042 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.175 -0.182 -0.012] | Goal: [ 0.112 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.04  -0.204 -0.008] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.162 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.263 -0.204  0.036] | Goal: [ 0.11  -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.041 -0.188  0.109] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.147 -0.165 -0.004] | Goal: [ 0.043 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.17  -0.003] | Goal: [ 0.112 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.016 -0.214 -0.003] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.159 -0.003] | Goal: [ 0.041 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.197 -0.012] | Goal: [ 0.044 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.151 -0.143  0.041] | Goal: [ 0.107 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.212  0.004] | Goal: [ 0.044 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.16  -0.194  0.007] | Goal: [ 0.037 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.036 -0.252 -0.005] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.105 -0.197  0.197] | Goal: [ 0.105 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.128 -0.148 -0.007] | Goal: [ 0.043 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.176 -0.149 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.027 -0.278 -0.008] | Goal: [ 0.11  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.261 -0.187  0.121] | Goal: [ 0.113 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.186 -0.153 -0.006] | Goal: [ 0.106 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.121  0.146] | Goal: [ 0.107 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.112 -0.157  0.032] | Goal: [ 0.035 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.065 -0.207 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.127 -0.159 -0.009] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.127 -0.138 -0.015] | Goal: [ 0.112 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.184 -0.006] | Goal: [ 0.042 -0.254  0.025]
# 📊 Step 120000 | ✅ Successes: 11 | ⏱️ Timeouts: 35
# time: 2025-06-19 23:19:56 📈 Step 120000 | Reward (last 20000): -4784.1912 | 🎯 Goal: [ 0.036 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.05  -0.167  0.104] | Goal: [ 0.036 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.19   0.03 ] | Goal: [ 0.105 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.159  0.018] | Goal: [ 0.11  -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.062 -0.168  0.101] | Goal: [ 0.039 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.021 -0.235  0.042] | Goal: [ 0.037 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.108 -0.186 -0.007] | Goal: [ 0.105 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.111  0.194] | Goal: [ 0.111 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.159 -0.126  0.026] | Goal: [ 0.106 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.144  0.117] | Goal: [ 0.045 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.03  -0.201  0.28 ] | Goal: [ 0.108 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.038 -0.185 -0.003] | Goal: [ 0.044 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.122 -0.013] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.031 -0.132  0.133] | Goal: [ 0.111 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.062 -0.217 -0.005] | Goal: [ 0.039 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.182 -0.14  -0.003] | Goal: [ 0.11  -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.092 -0.191 -0.004] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.054 -0.237 -0.008] | Goal: [ 0.044 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.034 -0.214  0.068] | Goal: [ 0.038 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.167 -0.115  0.097] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.165 -0.147 -0.006] | Goal: [ 0.04  -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.023 -0.21  -0.003] | Goal: [ 0.04  -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.16   0.128] | Goal: [ 0.108 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.208 -0.01 ] | Goal: [ 0.036 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.011 -0.208  0.119] | Goal: [ 0.11  -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.103  0.194] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.093 -0.176  0.01 ] | Goal: [ 0.043 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.163 -0.125  0.024] | Goal: [ 0.044 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.073 -0.294  0.077] | Goal: [ 0.113 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.331  0.052] | Goal: [ 0.041 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.127  0.132] | Goal: [ 0.105 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.164 -0.238  0.002] | Goal: [ 0.036 -0.245  0.025]
# 📊 Step 140000 | ✅ Successes: 24 | ⏱️ Timeouts: 31
# time: 2025-06-19 23:20:41 📈 Step 140000 | Reward (last 20000): -4548.9496 | 🎯 Goal: [ 0.113 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.204  0.076] | Goal: [ 0.042 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.027 -0.151  0.128] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.162  0.003] | Goal: [ 0.109 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.17  -0.126 -0.009] | Goal: [ 0.04  -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.181 -0.292  0.093] | Goal: [ 0.04  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.027 -0.233  0.003] | Goal: [ 0.108 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.177  0.106] | Goal: [ 0.036 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.066 -0.254 -0.011] | Goal: [ 0.045 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.123 -0.188 -0.004] | Goal: [ 0.037 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.227 -0.006] | Goal: [ 0.112 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.179 -0.007] | Goal: [ 0.105 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.116 -0.007] | Goal: [ 0.042 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.064 -0.105  0.288] | Goal: [ 0.108 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.128 -0.258 -0.006] | Goal: [ 0.037 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.007 -0.206  0.131] | Goal: [ 0.042 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.039 -0.091  0.152] | Goal: [ 0.043 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.323  0.147] | Goal: [ 0.113 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.153  0.05 ] | Goal: [ 0.112 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.158 -0.227 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.179 -0.196  0.   ] | Goal: [ 0.041 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.085 -0.186  0.084] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.014 -0.279 -0.008] | Goal: [ 0.112 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.183 -0.163 -0.01 ] | Goal: [ 0.041 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.132  0.166] | Goal: [ 0.036 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.162 -0.006] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.209 -0.008] | Goal: [ 0.042 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.069 -0.06   0.309] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.059 -0.345  0.084] | Goal: [ 0.044 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.104 -0.218 -0.008] | Goal: [ 0.107 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.215 -0.227  0.064] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.123 -0.138 -0.013] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.144 -0.318  0.131] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 160000 | ✅ Successes: 18 | ⏱️ Timeouts: 32
# time: 2025-06-19 23:21:25 📈 Step 160000 | Reward (last 20000): -4487.9375 | 🎯 Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.034 -0.229 -0.004] | Goal: [ 0.107 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.042 -0.19   0.083] | Goal: [ 0.042 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.113 -0.186  0.04 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.242  0.248] | Goal: [ 0.04  -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.126 -0.158  0.016] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.117 -0.178 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.184  0.091] | Goal: [ 0.037 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.169 -0.276  0.055] | Goal: [ 0.042 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.05  -0.123  0.194] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.064 -0.251  0.156] | Goal: [ 0.112 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.237 -0.009] | Goal: [ 0.107 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.086 -0.146  0.096] | Goal: [ 0.107 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.188  0.093] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.03  -0.236 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.08  -0.208 -0.011] | Goal: [ 0.044 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.172  0.079] | Goal: [ 0.038 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.099 -0.143  0.107] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.152  0.069] | Goal: [ 0.044 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.113 -0.077  0.131] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.208 -0.231  0.177] | Goal: [ 0.108 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.126 -0.142  0.094] | Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.124 -0.159 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.166 -0.208  0.049] | Goal: [ 0.107 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.091 -0.127  0.15 ] | Goal: [ 0.108 -0.319  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.082 -0.166  0.09 ] | Goal: [ 0.039 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.08  -0.187  0.165] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.152 -0.137  0.108] | Goal: [ 0.044 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.192  0.016] | Goal: [ 0.044 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.133  0.063] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.114 -0.16   0.133] | Goal: [ 0.042 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.127 -0.096  0.172] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.198 -0.009] | Goal: [ 0.043 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.084 -0.172 -0.013] | Goal: [ 0.115 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.184 -0.183  0.113] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.094 -0.206 -0.003] | Goal: [ 0.038 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.126 -0.007] | Goal: [ 0.039 -0.248  0.06 ]
# 📊 Step 180000 | ✅ Successes: 13 | ⏱️ Timeouts: 36
# time: 2025-06-19 23:22:09 📈 Step 180000 | Reward (last 20000): -4434.7861 | 🎯 Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.127 -0.195 -0.004] | Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.189 -0.157  0.136] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.189 -0.012] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.102 -0.297  0.058] | Goal: [ 0.037 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.125 -0.166 -0.011] | Goal: [ 0.114 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.161 -0.132  0.032] | Goal: [ 0.037 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.098 -0.069  0.143] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.002 -0.205 -0.011] | Goal: [ 0.035 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.158 -0.159 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.144 -0.183  0.029] | Goal: [ 0.115 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.186 -0.255  0.167] | Goal: [ 0.038 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.135 -0.183 -0.003] | Goal: [ 0.11  -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.185 -0.296  0.099] | Goal: [ 0.113 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.157  0.046] | Goal: [ 0.044 -0.315  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.154 -0.176 -0.011] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.04  -0.347  0.112] | Goal: [ 0.108 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.2   -0.262  0.151] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.198 -0.221  0.02 ] | Goal: [ 0.115 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.114  0.106] | Goal: [ 0.042 -0.318  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.008 -0.143  0.125] | Goal: [ 0.109 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.308  0.11 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.174 -0.171 -0.008] | Goal: [ 0.039 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.066 -0.254 -0.008] | Goal: [ 0.112 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.167  0.08 ] | Goal: [ 0.114 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.036 -0.234  0.145] | Goal: [ 0.035 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.089 -0.193 -0.011] | Goal: [ 0.108 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.146  0.08 ] | Goal: [ 0.106 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.131 -0.179 -0.004] | Goal: [ 0.038 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.22 -0.21  0.02] | Goal: [ 0.035 -0.323  0.06 ]
# 📊 Step 200000 | ✅ Successes: 25 | ⏱️ Timeouts: 29
# time: 2025-06-19 23:22:53 📈 Step 200000 | Reward (last 20000): -4403.0759 | 🎯 Goal: [ 0.036 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.009 -0.208  0.11 ] | Goal: [ 0.036 -0.253  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.171  0.071] | Goal: [ 0.037 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.109 -0.169  0.086] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.114 -0.166 -0.01 ] | Goal: [ 0.112 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.152 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.027 -0.335  0.043] | Goal: [ 0.039 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.118 -0.092  0.304] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.064 -0.33   0.055] | Goal: [ 0.043 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.135 -0.161  0.115] | Goal: [ 0.037 -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.22   0.236] | Goal: [ 0.037 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.138 -0.009] | Goal: [ 0.043 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.143 -0.171 -0.   ] | Goal: [ 0.107 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.227  0.005] | Goal: [ 0.106 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.147 -0.11   0.103] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.085  0.123] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.146 -0.148  0.026] | Goal: [ 0.105 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.142  0.095] | Goal: [ 0.108 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.125 -0.157  0.029] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.096 -0.13   0.116] | Goal: [ 0.106 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.178 -0.279  0.039] | Goal: [ 0.037 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.083 -0.115  0.127] | Goal: [ 0.044 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.207 -0.236  0.177] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.149 -0.154 -0.003] | Goal: [ 0.106 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.048 -0.093  0.217] | Goal: [ 0.04  -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.157 -0.146  0.101] | Goal: [ 0.114 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.089 -0.298  0.017] | Goal: [ 0.111 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.181 -0.163  0.078] | Goal: [ 0.11  -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.088 -0.218  0.13 ] | Goal: [ 0.038 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.168 -0.234  0.079] | Goal: [ 0.04  -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.095  0.137] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.067 -0.26   0.008] | Goal: [ 0.041 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.165 -0.124 -0.007] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.014 -0.121  0.167] | Goal: [ 0.04  -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.078 -0.322  0.033] | Goal: [ 0.108 -0.253  0.06 ]
# 📊 Step 220000 | ✅ Successes: 14 | ⏱️ Timeouts: 34
# time: 2025-06-19 23:23:37 📈 Step 220000 | Reward (last 20000): -4332.5918 | 🎯 Goal: [ 0.113 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.122 -0.197  0.166] | Goal: [ 0.113 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.15  -0.164  0.003] | Goal: [ 0.039 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.162  0.061] | Goal: [ 0.043 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.099 -0.222 -0.004] | Goal: [ 0.11  -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.159 -0.003] | Goal: [ 0.041 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.187  0.103] | Goal: [ 0.041 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.028 -0.068  0.24 ] | Goal: [ 0.04  -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.018 -0.323  0.159] | Goal: [ 0.109 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.121 -0.176 -0.009] | Goal: [ 0.112 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.015 -0.124  0.167] | Goal: [ 0.039 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.205 -0.01 ] | Goal: [ 0.114 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.189  0.012] | Goal: [ 0.113 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.157 -0.118  0.051] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.102 -0.21   0.065] | Goal: [ 0.113 -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.295  0.209] | Goal: [ 0.11  -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.063 -0.134  0.271] | Goal: [ 0.11  -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.149 -0.146 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.091 -0.275  0.026] | Goal: [ 0.107 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.036 -0.186 -0.002] | Goal: [ 0.112 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.148 -0.109  0.08 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.024 -0.205  0.102] | Goal: [ 0.036 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.176  0.125] | Goal: [ 0.044 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.083 -0.07   0.239] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.116 -0.286  0.121] | Goal: [ 0.108 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.028 -0.261 -0.009] | Goal: [ 0.042 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.139  0.072] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.151 -0.152 -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.1   -0.167  0.014] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.178 -0.14   0.104] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.158 -0.164 -0.01 ] | Goal: [ 0.042 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.132 -0.211 -0.005] | Goal: [ 0.112 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.009 -0.354  0.109] | Goal: [ 0.04  -0.318  0.025]
# 📊 Step 240000 | ✅ Successes: 23 | ⏱️ Timeouts: 32
# time: 2025-06-19 23:24:20 📈 Step 240000 | Reward (last 20000): -4275.927 | 🎯 Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.08  -0.092  0.188] | Goal: [ 0.039 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.166  0.258] | Goal: [ 0.11  -0.319  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.057 -0.309  0.037] | Goal: [ 0.041 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.048 -0.198  0.19 ] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.101 -0.152  0.106] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.133 -0.186  0.035] | Goal: [ 0.108 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.175 -0.125  0.01 ] | Goal: [ 0.042 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.165 -0.205  0.004] | Goal: [ 0.038 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.124 -0.175  0.099] | Goal: [ 0.043 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.013 -0.193 -0.007] | Goal: [ 0.039 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.118 -0.226 -0.01 ] | Goal: [ 0.041 -0.315  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.002 -0.204  0.001] | Goal: [ 0.036 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.235 -0.236  0.113] | Goal: [ 0.042 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.138 -0.168  0.212] | Goal: [ 0.036 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.032 -0.127  0.158] | Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.226 -0.259  0.096] | Goal: [ 0.107 -0.249  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.126 -0.287  0.013] | Goal: [ 0.04 -0.32  0.06]
# ⏱️ Timeout at Step 500 | EE: [ 0.019 -0.19   0.12 ] | Goal: [ 0.041 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.173 -0.251  0.052] | Goal: [ 0.037 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.007 -0.289  0.13 ] | Goal: [ 0.111 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.003 -0.295  0.052] | Goal: [ 0.106 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.043 -0.209  0.041] | Goal: [ 0.038 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.116 -0.151  0.043] | Goal: [ 0.113 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.07  -0.248 -0.005] | Goal: [ 0.04  -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.016 -0.257 -0.008] | Goal: [ 0.113 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.008 -0.213  0.102] | Goal: [ 0.04  -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.103 -0.12   0.119] | Goal: [ 0.11  -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.123 -0.144  0.071] | Goal: [ 0.04  -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.058 -0.27  -0.009] | Goal: [ 0.045 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.023 -0.19   0.183] | Goal: [ 0.043 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.13  -0.011] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 260000 | ✅ Successes: 23 | ⏱️ Timeouts: 31
# time: 2025-06-19 23:25:03 📈 Step 260000 | Reward (last 20000): -4101.5689 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.13  -0.148 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.005 -0.136  0.142] | Goal: [ 0.036 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.14  -0.132  0.081] | Goal: [ 0.114 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.045 -0.257 -0.006] | Goal: [ 0.106 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.155 -0.173 -0.007] | Goal: [ 0.113 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.001 -0.214 -0.006] | Goal: [ 0.108 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.098 -0.211 -0.012] | Goal: [ 0.036 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.051 -0.285  0.226] | Goal: [ 0.042 -0.318  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.049 -0.255 -0.   ] | Goal: [ 0.037 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.212 -0.193  0.193] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.067 -0.22  -0.007] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.072 -0.101  0.183] | Goal: [ 0.045 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.182 -0.254  0.148] | Goal: [ 0.036 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.078 -0.105  0.171] | Goal: [ 0.114 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.012 -0.037  0.294] | Goal: [ 0.04  -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.079 -0.151  0.122] | Goal: [ 0.114 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.263 -0.183  0.189] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.012 -0.206 -0.012] | Goal: [ 0.042 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.132 -0.158  0.009] | Goal: [ 0.037 -0.245  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.121 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.075 -0.302  0.194] | Goal: [ 0.109 -0.251  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.02  -0.294  0.155] | Goal: [ 0.036 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.148 -0.135 -0.014] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.122 -0.182  0.043] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.145 -0.212 -0.008] | Goal: [ 0.044 -0.247  0.025]
# 📊 Step 280000 | ✅ Successes: 34 | ⏱️ Timeouts: 25
# time: 2025-06-19 23:25:48 📈 Step 280000 | Reward (last 20000): -3993.0851 | 🎯 Goal: [ 0.037 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.105 -0.214 -0.005] | Goal: [ 0.037 -0.324  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.148 -0.149 -0.004] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.176 -0.172  0.145] | Goal: [ 0.038 -0.323  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.127 -0.158  0.117] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.04  -0.245 -0.006] | Goal: [ 0.035 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.126 -0.212  0.053] | Goal: [ 0.114 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.176 -0.253  0.058] | Goal: [ 0.038 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.007 -0.327  0.195] | Goal: [ 0.111 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.068 -0.336  0.107] | Goal: [ 0.044 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.235 -0.203  0.016] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.028 -0.028  0.336] | Goal: [ 0.113 -0.248  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.206  0.081] | Goal: [ 0.113 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.066 -0.216  0.06 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.032 -0.197 -0.01 ] | Goal: [ 0.044 -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.152 -0.16  -0.006] | Goal: [ 0.115 -0.316  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.053 -0.225  0.056] | Goal: [ 0.035 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.035 -0.23   0.174] | Goal: [ 0.04  -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.095 -0.295  0.155] | Goal: [ 0.04  -0.317  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.146 -0.211 -0.006] | Goal: [ 0.036 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.027 -0.176  0.101] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.171 -0.155 -0.009] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.031 -0.245  0.029] | Goal: [ 0.043 -0.254  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.008 -0.137  0.152] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.025 -0.328  0.111] | Goal: [ 0.11  -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.248 -0.249  0.155] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.207 -0.011] | Goal: [ 0.112 -0.317  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.227 -0.236  0.189] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.09  -0.253  0.002] | Goal: [-0.169 -0.221  0.03 ]
# 📊 Step 300000 | ✅ Successes: 34 | ⏱️ Timeouts: 28
# time: 2025-06-19 23:26:33 📈 Step 300000 | Reward (last 20000): -3951.2327 | 🎯 Goal: [ 0.037 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.232 -0.218  0.017] | Goal: [ 0.037 -0.323  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.185 -0.291  0.06 ] | Goal: [ 0.107 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.093 -0.106  0.137] | Goal: [ 0.113 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.106 -0.242 -0.012] | Goal: [ 0.042 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.11  -0.334  0.13 ] | Goal: [ 0.038 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.158  0.105] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.168 -0.264  0.141] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.17  -0.314  0.099] | Goal: [ 0.108 -0.322  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.246 -0.215  0.178] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.114 -0.183  0.052] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.136 -0.154  0.043] | Goal: [ 0.041 -0.248  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.169 -0.231  0.003] | Goal: [ 0.106 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.1   -0.108  0.123] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.087 -0.078  0.329] | Goal: [ 0.105 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.054 -0.234 -0.004] | Goal: [ 0.044 -0.25   0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.202 -0.221  0.038] | Goal: [ 0.113 -0.321  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.159 -0.169 -0.008] | Goal: [ 0.114 -0.324  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.239 -0.202  0.042] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.097 -0.327  0.151] | Goal: [ 0.041 -0.32   0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.033 -0.053  0.252] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.009 -0.266  0.134] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.029 -0.249  0.275] | Goal: [ 0.035 -0.255  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.116 -0.194 -0.006] | Goal: [-0.169 -0.221  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.105 -0.155 -0.008] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.18  -0.301  0.113] | Goal: [ 0.115 -0.321  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.261 -0.253  0.111] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 320000 | ✅ Successes: 36 | ⏱️ Timeouts: 26
# time: 2025-06-19 23:27:17 📈 Step 320000 | Reward (last 20000): -3848.1506 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.096 -0.171  0.016] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.022 -0.334  0.038] | Goal: [ 0.113 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.037 -0.314  0.08 ] | Goal: [ 0.106 -0.246  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.156 -0.147 -0.009] | Goal: [ 0.11  -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.128 -0.152  0.07 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.032 -0.218 -0.004] | Goal: [ 0.038 -0.253  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.176 -0.225  0.015] | Goal: [ 0.109 -0.322  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.156 -0.01 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.129 -0.163  0.005] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.137 -0.162 -0.008] | Goal: [ 0.114 -0.325  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.091 -0.344  0.096] | Goal: [ 0.038 -0.32   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.059 -0.217  0.093] | Goal: [ 0.107 -0.249  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.233 -0.167 -0.009] | Goal: [ 0.115 -0.325  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.099 -0.321  0.048] | Goal: [ 0.04  -0.255  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.187 -0.128 -0.015] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.128 -0.262  0.081] | Goal: [ 0.041 -0.246  0.025]
# ...
# time: 2025-06-20 10:54:19 📈 Step 1320000 | Reward (last 20000): 27320.8015 | 🎯 Goal: [ 0.04  -0.255  0.06 ]
# 📊 Step 1340000 | ✅ Successes: 13944 | ⏱️ Timeouts: 0
# time: 2025-06-20 11:36:04 📈 Step 1340000 | Reward (last 20000): 27244.4796 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 1360000 | ✅ Successes: 14040 | ⏱️ Timeouts: 0
# time: 2025-06-20 12:17:54 📈 Step 1360000 | Reward (last 20000): 27444.1683 | 🎯 Goal: [-0.169 -0.151  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.271  0.061] | Goal: [ 0.043 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.294  0.028] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.294  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.296  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.297  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.298  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.298  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.298  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.296  0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.296  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.298  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.296  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.298  0.031] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.294  0.028] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.293  0.026] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.297  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.299  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.3    0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.3    0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.298  0.032] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 1380000 | ✅ Successes: 6251 | ⏱️ Timeouts: 20
# time: 2025-06-20 12:36:53 📈 Step 1380000 | Reward (last 20000): 11715.6887 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.129 -0.303  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.3    0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.299  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.297  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.298  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.297  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.135 -0.299  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.297  0.027] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.298  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.3    0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.298  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.296  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.296  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.299  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.298  0.027] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.297  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.299  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.299  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.3    0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.135 -0.299  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.132 -0.299  0.029] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.298  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.302  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.298  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.299  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.299  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.301  0.031] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.298  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.301  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.143 -0.295  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.131 -0.3    0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.298  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.298  0.041] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.298  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.297  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.135 -0.3    0.031] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.3    0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.3    0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.299  0.032] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 1400000 | ✅ Successes: 373 | ⏱️ Timeouts: 39
# time: 2025-06-20 12:38:38 📈 Step 1400000 | Reward (last 20000): -133.381 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.296  0.031] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.133 -0.301  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.3    0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.302  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.296  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.3    0.031] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.297  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.301  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.301  0.032] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.301  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.299  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.301  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.301  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.302  0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.143 -0.301  0.039] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.301  0.034] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.3    0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.143 -0.297  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.051 -0.269  0.07 ] | Goal: [ 0.04  -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.301  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.302  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.276  0.038] | Goal: [ 0.038 -0.252  0.025]
# ⏱️ Timeout at Step 500 | EE: [-0.134 -0.305  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.302  0.041] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.298  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.303  0.043] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.141 -0.301  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.138 -0.304  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.145 -0.296  0.033] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.146 -0.299  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.145 -0.3    0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.301  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.135 -0.303  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.3    0.035] | Goal: [-0.169 -0.291  0.03 ]
# 📊 Step 1420000 | ✅ Successes: 649 | ⏱️ Timeouts: 34
# time: 2025-06-20 12:41:10 📈 Step 1420000 | Reward (last 20000): 476.3981 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.269  0.044] | Goal: [ 0.038 -0.247  0.025]
# ⏱️ Timeout at Step 500 | EE: [ 0.044 -0.278  0.062] | Goal: [ 0.038 -0.251  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.14  -0.305  0.04 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.143 -0.301  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.302  0.037] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.302  0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.137 -0.304  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.06  -0.271  0.072] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.3    0.036] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.139 -0.304  0.038] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.136 -0.297  0.03 ] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.144 -0.297  0.041] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [-0.142 -0.301  0.035] | Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.272  0.067] | Goal: [ 0.04  -0.247  0.06 ]
# 📊 Step 1440000 | ✅ Successes: 4846 | ⏱️ Timeouts: 14
# time: 2025-06-20 12:56:00 📈 Step 1440000 | Reward (last 20000): 8943.2858 | 🎯 Goal: [-0.169 -0.291  0.03 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.052 -0.277  0.06 ] | Goal: [ 0.037 -0.252  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.051 -0.27   0.059] | Goal: [ 0.039 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.049 -0.27   0.06 ] | Goal: [ 0.036 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.271  0.057] | Goal: [ 0.036 -0.245  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.057 -0.271  0.062] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.052 -0.268  0.059] | Goal: [ 0.038 -0.246  0.06 ]
# 📊 Step 1460000 | ✅ Successes: 10925 | ⏱️ Timeouts: 6
# time: 2025-06-20 13:28:47 📈 Step 1460000 | Reward (last 20000): 21155.9054 | 🎯 Goal: [ 0.038 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.271  0.057] | Goal: [ 0.038 -0.247  0.06 ]
# 📊 Step 1480000 | ✅ Successes: 13369 | ⏱️ Timeouts: 1
# time: 2025-06-20 14:08:52 📈 Step 1480000 | Reward (last 20000): 26048.1528 | 🎯 Goal: [ 0.108 -0.254  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.045 -0.272  0.069] | Goal: [ 0.035 -0.25   0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.055 -0.269  0.063] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.052 -0.272  0.068] | Goal: [ 0.044 -0.247  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.054 -0.272  0.066] | Goal: [ 0.042 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.035 -0.278  0.071] | Goal: [ 0.035 -0.246  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.047 -0.272  0.059] | Goal: [ 0.041 -0.247  0.06 ]
# 📊 Step 1500000 | ✅ Successes: 11496 | ⏱️ Timeouts: 6
# time: 2025-06-20 14:43:25 📈 Step 1500000 | Reward (last 20000): 22301.9945 | 🎯 Goal: [ 0.044 -0.316  0.06 ]
# ⏱️ Timeout at Step 500 | EE: [ 0.046 -0.273  0.06 ] | Goal: [ 0.038 -0.245  0.06 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      18 reward_logger = RewardAndGoalLoggingCallback(log_interval=20000)
#      20 # Train with logging
# ---> 21 model.learn(total_timesteps=2_000_000, callback=reward_logger)
#      23 env.close()
#      25 model.save("ppo_uarm_final_25_2")
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:71, in DummyVecEnv.step_wait(self)
#      68     if self.buf_dones[env_idx]:
#      69         # save final observation where user can get it, then reset
#      70         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 71         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      72     self._save_obs(env_idx, obs)
#      73 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/shimmy/openai_gym_compatibility.py:234, in GymV21CompatibilityV0.reset(self, seed, options)
#     229 if options is not None:
#     230     warn(
#     231         f"Gym v21 environment do not accept options as a reset parameter, options={options}"
#     232     )
# --> 234 obs = self.gym_env.reset()
#     236 if self.render_mode == "human":
#     237     self.render()
#
# File ~/git/ai_project/env.py:66, in UArmEnv.reset(self)
#      64 p.setGravity(0, 0, -9.81)
#      65 self.planeID = p.loadURDF("plane.urdf")
# ---> 66 self.robot.load('./urdf/UArm.urdf')
#      67 self.robot.reset_arm()
#      68 self.current_step = 0
#
# File ~/git/ai_project/robot.py:40, in UArm.load(self, urdf_path, use_fixed_base)
#      37     return
#      39 # print(f"[INFO] Trying to load URDF from: {abs_path}")
# ---> 40 self.id = p.loadURDF(abs_path, self.base_pos, self.base_ori, useFixedBase=use_fixed_base)
#      41 if self.id is None:
#      42     print(f"[ERROR] Failed to load URDF: {abs_path}")
#
# KeyboardInterrupt:

# %%
# env.close()

model.save("ppo_uarm_overtrained")
